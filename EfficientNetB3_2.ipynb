# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import roc_curve, precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
# Out:
# 2025-05-21 22:56:05.247649: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747846565.259921   11810 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747846565.263611   11810 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747846565.273137   11810 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747846565.273151   11810 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747846565.273153   11810 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747846565.273154   11810 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-21 22:56:05.276126: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_path= '/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/train'
val_path='/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/val'
test_path='/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test'

# %%
train_datagen = image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
val_datagen= image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_datagen= image.ImageDataGenerator()

# %%
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=True,
    class_mode = 'categorical')
validation_generator = val_datagen.flow_from_directory(
    val_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=False,
    class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=False,
    class_mode = 'categorical'
)
# Out:
# Found 20263 images belonging to 8 classes.
# Found 2540 images belonging to 8 classes.
# Found 2557 images belonging to 8 classes.

# %%
class_names = list(train_generator.class_indices.keys())
num_classes = len(class_names)
print(class_names)
# Out:
# ['AMD', 'CNV', 'CSR', 'DME', 'DR', 'DRUSEN', 'MH', 'NORMAL']

# %%
image_size = (224, 224)
batch_size = 8

# Function to load and preprocess images
def load_and_preprocess_image(file_path):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, image_size)
    img = tf.image.convert_image_dtype(img, tf.float32) / 255.0
    return img

# Function to get image paths and labels from a directory
def get_image_paths_and_labels(data_dir):
    image_paths = []
    labels = []
    class_names = sorted(os.listdir(data_dir))
    class_indices = {class_name: i for i, class_name in enumerate(class_names)}
    for class_name in class_names:
        class_path = os.path.join(data_dir, class_name)
        for filename in os.listdir(class_path):
            if filename.endswith(('.jpg', '.jpeg', '.png')):  # Adjust based on your file types
                image_paths.append(os.path.join(class_path, filename))
                labels.append(class_indices[class_name])
    return image_paths, tf.one_hot(labels, depth=len(class_names)) # One-hot encode labels

# Create training dataset
train_image_paths, train_labels = get_image_paths_and_labels(train_path)
train_dataset = tf.data.Dataset.from_tensor_slices((train_image_paths, train_labels))
train_dataset = train_dataset.map(lambda path, label: (load_and_preprocess_image(path), label),
                                  num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(buffer_size=len(train_image_paths))
train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# Create validation dataset
validation_image_paths, validation_labels = get_image_paths_and_labels(test_path)
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_image_paths, validation_labels))
validation_dataset = validation_dataset.map(lambda path, label: (load_and_preprocess_image(path), label),
                                           num_parallel_calls=tf.data.AUTOTUNE)
validation_dataset = validation_dataset.batch(batch_size)
validation_dataset = validation_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# I0000 00:00:1747846567.280704   11810 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5524 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
from tensorflow.keras import Sequential, layers

# Load the pre-trained EfficientNetB3 model (excluding the top classification layer)
base_model = tf.keras.applications.EfficientNetB3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = True

# Create a new sequential model
model = Sequential()

# Add the EfficientNetB3 base model
model.add(base_model)

# Add the convolutional layers you defined
# model.add(layers.Conv2D(filters=8, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding="same"))
# model.add(layers.BatchNormalization())
# model.add(layers.MaxPool2D(pool_size=(3, 3)))

model.add(layers.Flatten())
model.add(layers.Dense(8, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb3 (Functional)     │ (None, 7, 7, 1536)     │    10,783,535 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 75264)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │       602,120 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,385,655 (43.43 MB)
#  Trainable params: 11,298,352 (43.10 MB)
#  Non-trainable params: 87,303 (341.03 KB)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy','Precision','Recall','AUC'])

# %%
history = model.fit(
    train_generator,
    epochs=50,
    callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, mode='auto')],
    validation_data=validation_generator
    )
# Out:
# /home/nemo/.conda/envs/tf/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747846605.648466   11978 service.cc:152] XLA service 0x705578005ad0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747846605.648480   11978 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3050, Compute Capability 8.6
# 2025-05-21 22:56:46.838338: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747846611.868042   11978 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1747846662.036710   11978 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 332s 382ms/step - AUC: 0.9255 - Precision: 0.7632 - Recall: 0.7419 - accuracy: 0.7496 - loss: 1.4172 - val_AUC: 0.9249 - val_Precision: 0.7925 - val_Recall: 0.7862 - val_accuracy: 0.7898 - val_loss: 1.7210 - learning_rate: 0.0010
# Epoch 2/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 173s 272ms/step - AUC: 0.9701 - Precision: 0.8833 - Recall: 0.8759 - accuracy: 0.8795 - loss: 0.6944 - val_AUC: 0.9884 - val_Precision: 0.9307 - val_Recall: 0.9252 - val_accuracy: 0.9283 - val_loss: 0.2925 - learning_rate: 0.0010
# Epoch 3/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 173s 273ms/step - AUC: 0.9816 - Precision: 0.9111 - Recall: 0.9059 - accuracy: 0.9081 - loss: 0.4485 - val_AUC: 0.9666 - val_Precision: 0.8674 - val_Recall: 0.8472 - val_accuracy: 0.8563 - val_loss: 0.7456 - learning_rate: 0.0010
# Epoch 4/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 177s 278ms/step - AUC: 0.9791 - Precision: 0.9047 - Recall: 0.8983 - accuracy: 0.9011 - loss: 0.5124 - val_AUC: 0.9829 - val_Precision: 0.9249 - val_Recall: 0.9165 - val_accuracy: 0.9201 - val_loss: 0.4442 - learning_rate: 0.0010
# Epoch 5/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 178s 281ms/step - AUC: 0.9887 - Precision: 0.9346 - Recall: 0.9278 - accuracy: 0.9307 - loss: 0.3033 - val_AUC: 0.9808 - val_Precision: 0.9248 - val_Recall: 0.9197 - val_accuracy: 0.9220 - val_loss: 0.4526 - learning_rate: 0.0010
# Epoch 6/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 184s 290ms/step - AUC: 0.9873 - Precision: 0.9281 - Recall: 0.9199 - accuracy: 0.9228 - loss: 0.3572 - val_AUC: 0.9743 - val_Precision: 0.8902 - val_Recall: 0.8839 - val_accuracy: 0.8858 - val_loss: 0.6052 - learning_rate: 0.0010
# Epoch 7/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 176s 277ms/step - AUC: 0.9780 - Precision: 0.9057 - Recall: 0.8991 - accuracy: 0.9019 - loss: 0.5682 - val_AUC: 0.9899 - val_Precision: 0.9339 - val_Recall: 0.9240 - val_accuracy: 0.9283 - val_loss: 0.2893 - learning_rate: 0.0010
# Epoch 8/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 176s 277ms/step - AUC: 0.9882 - Precision: 0.9301 - Recall: 0.9232 - accuracy: 0.9260 - loss: 0.3509 - val_AUC: 0.9411 - val_Precision: 0.8131 - val_Recall: 0.8051 - val_accuracy: 0.8083 - val_loss: 1.2414 - learning_rate: 0.0010
# Epoch 9/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 174s 275ms/step - AUC: 0.9750 - Precision: 0.9046 - Recall: 0.8992 - accuracy: 0.9012 - loss: 0.6555 - val_AUC: 0.9949 - val_Precision: 0.9553 - val_Recall: 0.9512 - val_accuracy: 0.9535 - val_loss: 0.1758 - learning_rate: 0.0010
# Epoch 10/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 172s 271ms/step - AUC: 0.9882 - Precision: 0.9345 - Recall: 0.9267 - accuracy: 0.9302 - loss: 0.3228 - val_AUC: 0.7381 - val_Precision: 0.4836 - val_Recall: 0.4819 - val_accuracy: 0.4827 - val_loss: 11.7419 - learning_rate: 0.0010
# Epoch 11/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 165s 259ms/step - AUC: 0.9728 - Precision: 0.8887 - Recall: 0.8818 - accuracy: 0.8841 - loss: 0.7487 - val_AUC: 0.9850 - val_Precision: 0.9333 - val_Recall: 0.9260 - val_accuracy: 0.9295 - val_loss: 0.3727 - learning_rate: 0.0010
# Epoch 12/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 171s 269ms/step - AUC: 0.9902 - Precision: 0.9379 - Recall: 0.9309 - accuracy: 0.9340 - loss: 0.3229 - val_AUC: 0.9909 - val_Precision: 0.9470 - val_Recall: 0.9433 - val_accuracy: 0.9445 - val_loss: 0.2824 - learning_rate: 0.0010
# Epoch 13/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 170s 268ms/step - AUC: 0.9868 - Precision: 0.9317 - Recall: 0.9258 - accuracy: 0.9295 - loss: 0.3851 - val_AUC: 0.9504 - val_Precision: 0.8188 - val_Recall: 0.8146 - val_accuracy: 0.8161 - val_loss: 1.1551 - learning_rate: 0.0010
# Epoch 14/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - AUC: 0.9777 - Precision: 0.8973 - Recall: 0.8902 - accuracy: 0.8929 - loss: 0.5667
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 170s 268ms/step - AUC: 0.9778 - Precision: 0.8973 - Recall: 0.8903 - accuracy: 0.8929 - loss: 0.5665 - val_AUC: 0.9954 - val_Precision: 0.9470 - val_Recall: 0.9433 - val_accuracy: 0.9453 - val_loss: 0.1873 - learning_rate: 0.0010
# Epoch 15/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 179s 282ms/step - AUC: 0.9950 - Precision: 0.9498 - Recall: 0.9457 - accuracy: 0.9476 - loss: 0.1815 - val_AUC: 0.9965 - val_Precision: 0.9612 - val_Recall: 0.9559 - val_accuracy: 0.9591 - val_loss: 0.1399 - learning_rate: 1.0000e-04
# Epoch 16/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 167s 263ms/step - AUC: 0.9971 - Precision: 0.9602 - Recall: 0.9553 - accuracy: 0.9578 - loss: 0.1394 - val_AUC: 0.9978 - val_Precision: 0.9573 - val_Recall: 0.9528 - val_accuracy: 0.9539 - val_loss: 0.1277 - learning_rate: 1.0000e-04
# Epoch 17/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 168s 265ms/step - AUC: 0.9974 - Precision: 0.9645 - Recall: 0.9571 - accuracy: 0.9615 - loss: 0.1259 - val_AUC: 0.9963 - val_Precision: 0.9580 - val_Recall: 0.9528 - val_accuracy: 0.9551 - val_loss: 0.1353 - learning_rate: 1.0000e-04
# Epoch 18/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 166s 262ms/step - AUC: 0.9974 - Precision: 0.9630 - Recall: 0.9575 - accuracy: 0.9606 - loss: 0.1337 - val_AUC: 0.9977 - val_Precision: 0.9600 - val_Recall: 0.9543 - val_accuracy: 0.9579 - val_loss: 0.1242 - learning_rate: 1.0000e-04
# Epoch 19/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 160s 252ms/step - AUC: 0.9979 - Precision: 0.9662 - Recall: 0.9604 - accuracy: 0.9629 - loss: 0.1208 - val_AUC: 0.9980 - val_Precision: 0.9601 - val_Recall: 0.9563 - val_accuracy: 0.9587 - val_loss: 0.1284 - learning_rate: 1.0000e-04
# Epoch 20/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 159s 251ms/step - AUC: 0.9977 - Precision: 0.9651 - Recall: 0.9585 - accuracy: 0.9622 - loss: 0.1168 - val_AUC: 0.9980 - val_Precision: 0.9570 - val_Recall: 0.9551 - val_accuracy: 0.9563 - val_loss: 0.1204 - learning_rate: 1.0000e-04
# Epoch 21/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 159s 251ms/step - AUC: 0.9985 - Precision: 0.9673 - Recall: 0.9633 - accuracy: 0.9650 - loss: 0.1062 - val_AUC: 0.9986 - val_Precision: 0.9629 - val_Recall: 0.9602 - val_accuracy: 0.9614 - val_loss: 0.1032 - learning_rate: 1.0000e-04
# Epoch 22/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 164s 258ms/step - AUC: 0.9984 - Precision: 0.9694 - Recall: 0.9655 - accuracy: 0.9674 - loss: 0.1009 - val_AUC: 0.9974 - val_Precision: 0.9652 - val_Recall: 0.9614 - val_accuracy: 0.9634 - val_loss: 0.1132 - learning_rate: 1.0000e-04
# Epoch 23/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 166s 262ms/step - AUC: 0.9983 - Precision: 0.9692 - Recall: 0.9643 - accuracy: 0.9665 - loss: 0.1094 - val_AUC: 0.9978 - val_Precision: 0.9625 - val_Recall: 0.9594 - val_accuracy: 0.9602 - val_loss: 0.1183 - learning_rate: 1.0000e-04
# Epoch 24/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 167s 264ms/step - AUC: 0.9985 - Precision: 0.9688 - Recall: 0.9659 - accuracy: 0.9671 - loss: 0.0941 - val_AUC: 0.9980 - val_Precision: 0.9645 - val_Recall: 0.9622 - val_accuracy: 0.9626 - val_loss: 0.1078 - learning_rate: 1.0000e-04
# Epoch 25/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 161s 254ms/step - AUC: 0.9981 - Precision: 0.9693 - Recall: 0.9653 - accuracy: 0.9674 - loss: 0.1055 - val_AUC: 0.9984 - val_Precision: 0.9644 - val_Recall: 0.9606 - val_accuracy: 0.9630 - val_loss: 0.1033 - learning_rate: 1.0000e-04
# Epoch 26/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - AUC: 0.9982 - Precision: 0.9710 - Recall: 0.9685 - accuracy: 0.9698 - loss: 0.0943
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 159s 251ms/step - AUC: 0.9982 - Precision: 0.9710 - Recall: 0.9685 - accuracy: 0.9698 - loss: 0.0943 - val_AUC: 0.9982 - val_Precision: 0.9653 - val_Recall: 0.9638 - val_accuracy: 0.9642 - val_loss: 0.1046 - learning_rate: 1.0000e-04
# Epoch 27/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 167s 263ms/step - AUC: 0.9988 - Precision: 0.9748 - Recall: 0.9714 - accuracy: 0.9733 - loss: 0.0830 - val_AUC: 0.9979 - val_Precision: 0.9645 - val_Recall: 0.9622 - val_accuracy: 0.9630 - val_loss: 0.1112 - learning_rate: 1.0000e-05
# Epoch 28/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 171s 269ms/step - AUC: 0.9983 - Precision: 0.9717 - Recall: 0.9687 - accuracy: 0.9700 - loss: 0.0940 - val_AUC: 0.9984 - val_Precision: 0.9672 - val_Recall: 0.9646 - val_accuracy: 0.9657 - val_loss: 0.1009 - learning_rate: 1.0000e-05
# Epoch 29/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 170s 268ms/step - AUC: 0.9991 - Precision: 0.9734 - Recall: 0.9706 - accuracy: 0.9726 - loss: 0.0794 - val_AUC: 0.9980 - val_Precision: 0.9668 - val_Recall: 0.9642 - val_accuracy: 0.9661 - val_loss: 0.0995 - learning_rate: 1.0000e-05
# Epoch 30/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 168s 265ms/step - AUC: 0.9986 - Precision: 0.9740 - Recall: 0.9719 - accuracy: 0.9731 - loss: 0.0845 - val_AUC: 0.9980 - val_Precision: 0.9649 - val_Recall: 0.9634 - val_accuracy: 0.9642 - val_loss: 0.1023 - learning_rate: 1.0000e-05
# Epoch 31/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 165s 260ms/step - AUC: 0.9988 - Precision: 0.9743 - Recall: 0.9714 - accuracy: 0.9728 - loss: 0.0831 - val_AUC: 0.9985 - val_Precision: 0.9684 - val_Recall: 0.9665 - val_accuracy: 0.9669 - val_loss: 0.1008 - learning_rate: 1.0000e-05
# Epoch 32/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 167s 263ms/step - AUC: 0.9990 - Precision: 0.9737 - Recall: 0.9707 - accuracy: 0.9718 - loss: 0.0836 - val_AUC: 0.9977 - val_Precision: 0.9688 - val_Recall: 0.9673 - val_accuracy: 0.9677 - val_loss: 0.1076 - learning_rate: 1.0000e-05
# Epoch 33/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 171s 270ms/step - AUC: 0.9988 - Precision: 0.9747 - Recall: 0.9723 - accuracy: 0.9738 - loss: 0.0817 - val_AUC: 0.9982 - val_Precision: 0.9665 - val_Recall: 0.9650 - val_accuracy: 0.9654 - val_loss: 0.1071 - learning_rate: 1.0000e-05
# Epoch 34/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 170s 268ms/step - AUC: 0.9990 - Precision: 0.9771 - Recall: 0.9749 - accuracy: 0.9754 - loss: 0.0757 - val_AUC: 0.9980 - val_Precision: 0.9673 - val_Recall: 0.9661 - val_accuracy: 0.9665 - val_loss: 0.0968 - learning_rate: 1.0000e-05
# Epoch 35/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 166s 262ms/step - AUC: 0.9989 - Precision: 0.9755 - Recall: 0.9734 - accuracy: 0.9745 - loss: 0.0782 - val_AUC: 0.9989 - val_Precision: 0.9669 - val_Recall: 0.9661 - val_accuracy: 0.9665 - val_loss: 0.0946 - learning_rate: 1.0000e-05
# Epoch 36/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 164s 259ms/step - AUC: 0.9991 - Precision: 0.9780 - Recall: 0.9759 - accuracy: 0.9771 - loss: 0.0725 - val_AUC: 0.9986 - val_Precision: 0.9657 - val_Recall: 0.9630 - val_accuracy: 0.9638 - val_loss: 0.1023 - learning_rate: 1.0000e-05
# Epoch 37/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 165s 260ms/step - AUC: 0.9990 - Precision: 0.9772 - Recall: 0.9749 - accuracy: 0.9760 - loss: 0.0758 - val_AUC: 0.9988 - val_Precision: 0.9704 - val_Recall: 0.9689 - val_accuracy: 0.9693 - val_loss: 0.0881 - learning_rate: 1.0000e-05
# Epoch 38/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 166s 262ms/step - AUC: 0.9989 - Precision: 0.9764 - Recall: 0.9738 - accuracy: 0.9748 - loss: 0.0741 - val_AUC: 0.9981 - val_Precision: 0.9704 - val_Recall: 0.9669 - val_accuracy: 0.9681 - val_loss: 0.0946 - learning_rate: 1.0000e-05
# Epoch 39/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 165s 260ms/step - AUC: 0.9993 - Precision: 0.9765 - Recall: 0.9749 - accuracy: 0.9757 - loss: 0.0703 - val_AUC: 0.9987 - val_Precision: 0.9688 - val_Recall: 0.9665 - val_accuracy: 0.9677 - val_loss: 0.0929 - learning_rate: 1.0000e-05
# Epoch 40/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 165s 259ms/step - AUC: 0.9989 - Precision: 0.9760 - Recall: 0.9738 - accuracy: 0.9748 - loss: 0.0737 - val_AUC: 0.9983 - val_Precision: 0.9680 - val_Recall: 0.9657 - val_accuracy: 0.9681 - val_loss: 0.0981 - learning_rate: 1.0000e-05
# Epoch 41/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 166s 261ms/step - AUC: 0.9989 - Precision: 0.9743 - Recall: 0.9715 - accuracy: 0.9725 - loss: 0.0801 - val_AUC: 0.9991 - val_Precision: 0.9653 - val_Recall: 0.9634 - val_accuracy: 0.9646 - val_loss: 0.0930 - learning_rate: 1.0000e-05
# Epoch 42/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - AUC: 0.9987 - Precision: 0.9767 - Recall: 0.9747 - accuracy: 0.9759 - loss: 0.0776
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 169s 267ms/step - AUC: 0.9987 - Precision: 0.9767 - Recall: 0.9747 - accuracy: 0.9759 - loss: 0.0776 - val_AUC: 0.9986 - val_Precision: 0.9684 - val_Recall: 0.9657 - val_accuracy: 0.9665 - val_loss: 0.0903 - learning_rate: 1.0000e-05
# Epoch 43/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 166s 262ms/step - AUC: 0.9992 - Precision: 0.9785 - Recall: 0.9755 - accuracy: 0.9768 - loss: 0.0675 - val_AUC: 0.9984 - val_Precision: 0.9641 - val_Recall: 0.9622 - val_accuracy: 0.9630 - val_loss: 0.1041 - learning_rate: 1.0000e-06
# Epoch 44/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 166s 261ms/step - AUC: 0.9988 - Precision: 0.9741 - Recall: 0.9721 - accuracy: 0.9729 - loss: 0.0821 - val_AUC: 0.9982 - val_Precision: 0.9661 - val_Recall: 0.9654 - val_accuracy: 0.9661 - val_loss: 0.1036 - learning_rate: 1.0000e-06
# Epoch 45/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 170s 267ms/step - AUC: 0.9989 - Precision: 0.9775 - Recall: 0.9755 - accuracy: 0.9764 - loss: 0.0747 - val_AUC: 0.9978 - val_Precision: 0.9676 - val_Recall: 0.9650 - val_accuracy: 0.9661 - val_loss: 0.1041 - learning_rate: 1.0000e-06
# Epoch 46/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 160s 252ms/step - AUC: 0.9993 - Precision: 0.9767 - Recall: 0.9737 - accuracy: 0.9754 - loss: 0.0735 - val_AUC: 0.9985 - val_Precision: 0.9685 - val_Recall: 0.9673 - val_accuracy: 0.9673 - val_loss: 0.0940 - learning_rate: 1.0000e-06
# Epoch 47/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - AUC: 0.9990 - Precision: 0.9760 - Recall: 0.9733 - accuracy: 0.9751 - loss: 0.0781
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 159s 251ms/step - AUC: 0.9990 - Precision: 0.9760 - Recall: 0.9733 - accuracy: 0.9751 - loss: 0.0781 - val_AUC: 0.9981 - val_Precision: 0.9684 - val_Recall: 0.9654 - val_accuracy: 0.9673 - val_loss: 0.0979 - learning_rate: 1.0000e-06
# Epoch 48/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 159s 251ms/step - AUC: 0.9989 - Precision: 0.9772 - Recall: 0.9749 - accuracy: 0.9762 - loss: 0.0739 - val_AUC: 0.9987 - val_Precision: 0.9641 - val_Recall: 0.9618 - val_accuracy: 0.9622 - val_loss: 0.1023 - learning_rate: 1.0000e-07
# Epoch 49/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 160s 252ms/step - AUC: 0.9992 - Precision: 0.9749 - Recall: 0.9732 - accuracy: 0.9738 - loss: 0.0749 - val_AUC: 0.9985 - val_Precision: 0.9684 - val_Recall: 0.9657 - val_accuracy: 0.9665 - val_loss: 0.0970 - learning_rate: 1.0000e-07
# Epoch 50/50
# 634/634 ━━━━━━━━━━━━━━━━━━━━ 160s 252ms/step - AUC: 0.9990 - Precision: 0.9763 - Recall: 0.9738 - accuracy: 0.9751 - loss: 0.0756 - val_AUC: 0.9984 - val_Precision: 0.9661 - val_Recall: 0.9650 - val_accuracy: 0.9650 - val_loss: 0.0940 - learning_rate: 1.0000e-07

# %%
model.save('all_models/EfficientNetB3_2.keras')

# %%
model.evaluate(test_generator)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 23s 293ms/step - AUC: 0.9984 - Precision: 0.9778 - Recall: 0.9752 - accuracy: 0.9757 - loss: 0.0692
# [0.07500358670949936,
#  0.9745795726776123,
#  0.9772370457649231,
#  0.9737974405288696,
#  0.9987271428108215]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.title("Learning curve", fontsize=16)
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend()
plt.savefig('learning_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Accuracy", fontsize=16)
plt.plot(history.history["accuracy"], label="Accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('accuracy_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Loss", fontsize=16)
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('loss_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Precision", fontsize=16)
plt.plot(history.history["Precision"], label="precision")
plt.plot(history.history["val_Precision"], label="val_precision")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('precision_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Recall", fontsize=16)
plt.plot(history.history["Recall"], label="recall")
plt.plot(history.history["val_Recall"], label="val_recall")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('recall_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation AUC", fontsize=16)
plt.plot(history.history["AUC"], label="AUC")
plt.plot(history.history["val_AUC"], label="val_AUC")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('auc_curve.pdf')

# %%
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step

# %%
# Binarize true labels
y_true_bin = label_binarize(y_true, classes=list(range(len(class_names))))

plt.figure(figsize=(10, 8))
for i in range(len(class_names)):
    precision, recall, _ = precision_recall_curve(
        y_true_bin[:, i], y_pred_probs[:, i])
    plt.plot(recall, precision, lw=2, label=f'{class_names[i]}')

plt.xlabel('Recall', fontsize=14)
plt.ylabel('Precision', fontsize=14)
plt.title('Precision-Recall Curve', fontsize=16)
plt.legend(loc='best')
plt.grid(True)
plt.savefig('precision_recall_curve.pdf')
plt.show()

# %%
# ROC Curve
y_true_bin = label_binarize(y_true, classes=list(range(num_classes)))
fpr = dict()
tpr = dict()
roc_auc = dict()

plt.figure(figsize=(10, 8))
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    plt.plot(fpr[i], tpr[i],
             label=f'{class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve', fontsize=16)
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.legend(loc='lower right')
plt.grid()
plt.savefig('roc_curve.pdf')
plt.show()

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img('/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test/CSR/csr_train_2348.jpg',target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,axis=1)
if a==0:
      op="AMD"   
elif a==1:
    op='CNV'
elif a==2:
    op='CSR'
elif a==3:
    op='DME'
elif a==4:
    op='DR'
elif a==5:
    op='DRUSEN'
elif a==6:
    op='MH'
else:
      op="Normal"
plt.imshow(img)
print("THE UPLOADED OCT IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# [[9.4497925e-26 5.9249453e-29 1.0000000e+00 2.0132455e-41 9.5554075e-29
#   1.0750909e-33 1.6421983e-24 3.3981595e-34]]
# THE UPLOADED OCT IMAGE IS: CSR

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img('/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test/NORMAL/no_2497093_3.jpg',target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,axis=1)
if a==0:
      op="AMD"   
elif a==1:
    op='CNV'
elif a==2:
    op='CSR'
elif a==3:
    op='DME'
elif a==4:
    op='DR'
elif a==5:
    op='DRUSEN'
elif a==6:
    op='MH'
else:
      op="Normal"
plt.imshow(img)
print("THE UPLOADED OCT IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[3.8560789e-02 3.5132402e-06 1.5118861e-08 3.8113233e-04 2.6468389e-10
#   9.5995369e-05 1.8996499e-08 9.6095860e-01]]
# THE UPLOADED OCT IMAGE IS: Normal

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Get true labels
y_true = validation_generator.classes

# Predict probabilities
y_pred_prob = model.predict(validation_generator)

# Convert probabilities to class indices
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 21s 259ms/step

# %%
class_labels = list(validation_generator.class_indices.keys())

# %%
cm = confusion_matrix(y_true, y_pred)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("EfficientNetB3 Confusion Matrix", fontsize=16)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.show()
plt.savefig('confusion_matrix.pdf')

# %%
cm_normalized = confusion_matrix(y_true, y_pred, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("Normalized Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report


report = classification_report(y_true, y_pred, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          AMD       1.00      0.99      0.99       436
#          CNV       0.95      0.89      0.92       299
#          CSR       1.00      1.00      1.00       299
#          DME       0.94      0.95      0.94       314
#           DR       1.00      1.00      1.00       299
#       DRUSEN       0.91      0.93      0.92       299
#           MH       1.00      1.00      1.00       273
#       NORMAL       0.93      0.95      0.94       321
#
#     accuracy                           0.97      2540
#    macro avg       0.97      0.96      0.96      2540
# weighted avg       0.97      0.97      0.97      2540

# %% [markdown]
# ## Inference Time

# %%
import time
import numpy as np

# Assuming 'model' is your trained Keras model
# Assuming 'validation_generator' or a similar data source is available

# --- Prepare your inference data ---
# Get one batch for inference timing.
# Make sure validation_generator is properly initialized and can yield a batch.
# If your generator shuffles, reset it for consistent batch content if needed.
validation_generator.reset()
X_inference_batch, _ = next(validation_generator) # Use next() to get a single batch

print(f"Shape of inference batch: {X_inference_batch.shape}")
print(f"Batch size: {X_inference_batch.shape[0]}")

# --- 1. Warm-up runs (recommended) ---
print("\nPerforming warm-up runs...")
for _ in range(5): # Run 5 warm-up predictions
    _ = model.predict(X_inference_batch, verbose=0)
print("Warm-up complete.")

# --- 2. Measure inference time for a single batch (per step) ---
num_measurements = 100 # Number of times to repeat the measurement for averaging
inference_times_sec_per_step = []

print(f"\nMeasuring inference time over {num_measurements} repetitions...")
for _ in range(num_measurements):
    start_time = time.time()
    _ = model.predict(X_inference_batch, verbose=0) # Set verbose=0 to suppress progress bar
    end_time = time.time()
    inference_times_sec_per_step.append(end_time - start_time)

# Calculate average time per step in seconds
average_inference_time_sec_per_step = np.mean(inference_times_sec_per_step)
std_inference_time_sec_per_step = np.std(inference_times_sec_per_step)

# Convert to milliseconds per step
average_inference_time_ms_per_step = average_inference_time_sec_per_step * 1000
std_inference_time_ms_per_step = std_inference_time_sec_per_step * 1000

print(f"\nAverage inference time per step (batch size {X_inference_batch.shape[0]}):")
print(f"  {average_inference_time_ms_per_step:.4f} ms/step (Std Dev: {std_inference_time_ms_per_step:.4f} ms/step)")

# Optional: Calculate ms/sample if desired
samples_in_batch = X_inference_batch.shape[0]
if samples_in_batch > 0:
    average_inference_time_ms_per_sample = average_inference_time_ms_per_step / samples_in_batch
    print(f"  {average_inference_time_ms_per_sample:.4f} ms/sample")

# --- Example for total inference time over the whole validation set ---
# If you want to know the ms/step for the entire generator, you would need to
# divide the total inference time by the number of steps (batches) in the generator.

print("\nMeasuring total inference time for the entire validation set...")
validation_generator.reset() # Reset generator for a full pass
num_validation_steps = len(validation_generator) # Get the total number of batches

overall_inference_start_time = time.time()
_ = model.predict(validation_generator, verbose=1) # verbose=1 to see progress
overall_inference_end_time = time.time()

total_validation_inference_time_sec = overall_inference_end_time - overall_inference_start_time
total_validation_inference_time_ms = total_validation_inference_time_sec * 1000

# Calculate average ms/step for the entire validation set pass
if num_validation_steps > 0:
    average_ms_per_step_full_pass = total_validation_inference_time_ms / num_validation_steps
    print(f"Total inference time for validation set: {total_validation_inference_time_ms:.2f} ms")
    print(f"Average ms/step over entire validation set ({num_validation_steps} steps): {average_ms_per_step_full_pass:.4f} ms/step")
else:
    print("Validation generator has no steps.")
# Out:
# Shape of inference batch: (8, 224, 224, 3)
# Batch size: 8
#
# Performing warm-up runs...
# Warm-up complete.
#
# Measuring inference time over 100 repetitions...
#
# Average inference time per step (batch size 8):
#   75.0213 ms/step (Std Dev: 3.5344 ms/step)
#   9.3777 ms/sample
#
# Measuring total inference time for the entire validation set...
# /home/nemo/.conda/envs/tf/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 318/318 ━━━━━━━━━━━━━━━━━━━━ 28s 80ms/step
# Total inference time for validation set: 28628.01 ms
# Average ms/step over entire validation set (318 steps): 90.0252 ms/step

# %%
history.history.keys()
# Out:
# dict_keys(['AUC', 'Precision', 'Recall', 'accuracy', 'loss', 'val_AUC', 'val_Precision', 'val_Recall', 'val_accuracy', 'val_loss', 'learning_rate'])

# %%
history.params
# Out:
# {'verbose': 'auto', 'epochs': 50, 'steps': 634}

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
print(tf.keras.__version__)
# Out:
# 3.9.2
