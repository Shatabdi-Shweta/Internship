# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import roc_curve, precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
# Out:
# 2025-05-22 01:53:55.119182: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747857235.131677   70756 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747857235.135332   70756 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747857235.144826   70756 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747857235.144841   70756 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747857235.144842   70756 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747857235.144843   70756 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-22 01:53:55.148032: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_path= '/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/train'
val_path='/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/val'
test_path='/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test'

# %%
train_datagen = image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
val_datagen= image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_datagen= image.ImageDataGenerator()

# %%
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=True,
    class_mode = 'categorical')
validation_generator = val_datagen.flow_from_directory(
    val_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=False,
    class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=False,
    class_mode = 'categorical'
)
# Out:
# Found 20263 images belonging to 8 classes.
# Found 2540 images belonging to 8 classes.
# Found 2557 images belonging to 8 classes.

# %%
class_names = list(train_generator.class_indices.keys())
num_classes = len(class_names)
print(class_names)
# Out:
# ['AMD', 'CNV', 'CSR', 'DME', 'DR', 'DRUSEN', 'MH', 'NORMAL']

# %%
image_size = (224, 224)
batch_size = 8

# Function to load and preprocess images
def load_and_preprocess_image(file_path):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, image_size)
    img = tf.image.convert_image_dtype(img, tf.float32) / 255.0
    return img

# Function to get image paths and labels from a directory
def get_image_paths_and_labels(data_dir):
    image_paths = []
    labels = []
    class_names = sorted(os.listdir(data_dir))
    class_indices = {class_name: i for i, class_name in enumerate(class_names)}
    for class_name in class_names:
        class_path = os.path.join(data_dir, class_name)
        for filename in os.listdir(class_path):
            if filename.endswith(('.jpg', '.jpeg', '.png')):  # Adjust based on your file types
                image_paths.append(os.path.join(class_path, filename))
                labels.append(class_indices[class_name])
    return image_paths, tf.one_hot(labels, depth=len(class_names)) # One-hot encode labels

# Create training dataset
train_image_paths, train_labels = get_image_paths_and_labels(train_path)
train_dataset = tf.data.Dataset.from_tensor_slices((train_image_paths, train_labels))
train_dataset = train_dataset.map(lambda path, label: (load_and_preprocess_image(path), label),
                                  num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(buffer_size=len(train_image_paths))
train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# Create validation dataset
validation_image_paths, validation_labels = get_image_paths_and_labels(test_path)
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_image_paths, validation_labels))
validation_dataset = validation_dataset.map(lambda path, label: (load_and_preprocess_image(path), label),
                                           num_parallel_calls=tf.data.AUTOTUNE)
validation_dataset = validation_dataset.batch(batch_size)
validation_dataset = validation_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# I0000 00:00:1747857285.805143   70756 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5623 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
from tensorflow.keras import Sequential, layers

# Load the pre-trained EfficientNetB3 model (excluding the top classification layer)
base_model = tf.keras.applications.EfficientNetV2B0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = True

# Create a new sequential model
model = Sequential()

# Add the EfficientNetB3 base model
model.add(base_model)

# Add the convolutional layers you defined
# model.add(layers.Conv2D(filters=8, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding="same"))
# model.add(layers.BatchNormalization())
# model.add(layers.MaxPool2D(pool_size=(3, 3)))

model.add(layers.Flatten())
model.add(layers.Dense(8, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetv2-b0 (Functional)  │ (None, 7, 7, 1280)     │     5,919,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 62720)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │       501,768 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,421,080 (24.49 MB)
#  Trainable params: 6,360,472 (24.26 MB)
#  Non-trainable params: 60,608 (236.75 KB)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.AdamW(),
              metrics=['accuracy','Precision','Recall','AUC'])

# %%
history = model.fit(
    train_generator,
    epochs=50,
    callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, mode='auto')],
    validation_data=validation_generator
    )
# Out:
# Epoch 1/50
# /home/nemo/.conda/envs/tf/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747857325.009747   71073 service.cc:152] XLA service 0x7b4cfc0027c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747857325.009762   71073 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3050, Compute Capability 8.6
# 2025-05-22 01:55:25.866905: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747857329.269856   71073 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-05-22 01:55:57.116448: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 404 bytes spill stores, 388 bytes spill loads
#    3/2533 ━━━━━━━━━━━━━━━━━━━━ 2:06 50ms/step - AUC: 0.7411 - Precision: 0.5972 - Recall: 0.2847 - accuracy: 0.4375 - loss: 1.8757
# I0000 00:00:1747857357.389312   71073 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 267s 83ms/step - AUC: 0.8773 - Precision: 0.6633 - Recall: 0.6442 - accuracy: 0.6529 - loss: 2.3993 - val_AUC: 0.9480 - val_Precision: 0.8419 - val_Recall: 0.8386 - val_accuracy: 0.8398 - val_loss: 1.0729 - learning_rate: 0.0010
# Epoch 2/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 177s 70ms/step - AUC: 0.9283 - Precision: 0.7796 - Recall: 0.7719 - accuracy: 0.7758 - loss: 1.5475 - val_AUC: 0.9298 - val_Precision: 0.7412 - val_Recall: 0.7272 - val_accuracy: 0.7346 - val_loss: 1.3494 - learning_rate: 0.0010
# Epoch 3/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 175s 69ms/step - AUC: 0.9015 - Precision: 0.6918 - Recall: 0.6773 - accuracy: 0.6843 - loss: 1.8447 - val_AUC: 0.9457 - val_Precision: 0.7710 - val_Recall: 0.7543 - val_accuracy: 0.7618 - val_loss: 1.0339 - learning_rate: 0.0010
# Epoch 4/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 179s 71ms/step - AUC: 0.9009 - Precision: 0.6645 - Recall: 0.6436 - accuracy: 0.6524 - loss: 1.7184 - val_AUC: 0.9690 - val_Precision: 0.8427 - val_Recall: 0.8287 - val_accuracy: 0.8339 - val_loss: 0.6850 - learning_rate: 0.0010
# Epoch 5/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 174s 69ms/step - AUC: 0.9319 - Precision: 0.7357 - Recall: 0.7166 - accuracy: 0.7262 - loss: 1.2733 - val_AUC: 0.9419 - val_Precision: 0.7627 - val_Recall: 0.7339 - val_accuracy: 0.7453 - val_loss: 1.0237 - learning_rate: 0.0010
# Epoch 6/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 172s 68ms/step - AUC: 0.9252 - Precision: 0.7082 - Recall: 0.6825 - accuracy: 0.6949 - loss: 1.3102 - val_AUC: 0.9585 - val_Precision: 0.8054 - val_Recall: 0.7823 - val_accuracy: 0.7909 - val_loss: 0.8232 - learning_rate: 0.0010
# Epoch 7/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 172s 68ms/step - AUC: 0.9424 - Precision: 0.7701 - Recall: 0.7531 - accuracy: 0.7611 - loss: 1.0961 - val_AUC: 0.9679 - val_Precision: 0.8381 - val_Recall: 0.8252 - val_accuracy: 0.8299 - val_loss: 0.6403 - learning_rate: 0.0010
# Epoch 8/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 173s 68ms/step - AUC: 0.9565 - Precision: 0.7971 - Recall: 0.7758 - accuracy: 0.7859 - loss: 0.8606 - val_AUC: 0.9742 - val_Precision: 0.8376 - val_Recall: 0.8122 - val_accuracy: 0.8252 - val_loss: 0.6232 - learning_rate: 0.0010
# Epoch 9/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 174s 69ms/step - AUC: 0.9576 - Precision: 0.8012 - Recall: 0.7817 - accuracy: 0.7888 - loss: 0.8524 - val_AUC: 0.9790 - val_Precision: 0.8767 - val_Recall: 0.8654 - val_accuracy: 0.8693 - val_loss: 0.5042 - learning_rate: 0.0010
# Epoch 10/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 177s 70ms/step - AUC: 0.9480 - Precision: 0.7765 - Recall: 0.7547 - accuracy: 0.7636 - loss: 1.0023 - val_AUC: 0.9815 - val_Precision: 0.8709 - val_Recall: 0.8681 - val_accuracy: 0.8689 - val_loss: 0.4493 - learning_rate: 0.0010
# Epoch 11/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 174s 69ms/step - AUC: 0.9668 - Precision: 0.8281 - Recall: 0.8111 - accuracy: 0.8184 - loss: 0.7022 - val_AUC: 0.9789 - val_Precision: 0.8688 - val_Recall: 0.8579 - val_accuracy: 0.8630 - val_loss: 0.5115 - learning_rate: 0.0010
# Epoch 12/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 178s 70ms/step - AUC: 0.9601 - Precision: 0.8108 - Recall: 0.7882 - accuracy: 0.7981 - loss: 0.7940 - val_AUC: 0.9709 - val_Precision: 0.8386 - val_Recall: 0.8224 - val_accuracy: 0.8287 - val_loss: 1.4222 - learning_rate: 0.0010
# Epoch 13/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 180s 71ms/step - AUC: 0.9694 - Precision: 0.8329 - Recall: 0.8170 - accuracy: 0.8253 - loss: 0.6598 - val_AUC: 0.9847 - val_Precision: 0.8918 - val_Recall: 0.8791 - val_accuracy: 0.8831 - val_loss: 0.4211 - learning_rate: 0.0010
# Epoch 14/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 173s 68ms/step - AUC: 0.9711 - Precision: 0.8444 - Recall: 0.8290 - accuracy: 0.8356 - loss: 0.6209 - val_AUC: 0.9910 - val_Precision: 0.9161 - val_Recall: 0.9031 - val_accuracy: 0.9091 - val_loss: 0.3792 - learning_rate: 0.0010
# Epoch 15/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 174s 69ms/step - AUC: 0.9853 - Precision: 0.8913 - Recall: 0.8755 - accuracy: 0.8824 - loss: 0.3969 - val_AUC: 0.9840 - val_Precision: 0.8888 - val_Recall: 0.8713 - val_accuracy: 0.8803 - val_loss: 0.3913 - learning_rate: 0.0010
# Epoch 16/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 178s 70ms/step - AUC: 0.9859 - Precision: 0.8975 - Recall: 0.8847 - accuracy: 0.8904 - loss: 0.3732 - val_AUC: 0.9860 - val_Precision: 0.9063 - val_Recall: 0.8988 - val_accuracy: 0.9016 - val_loss: 0.3700 - learning_rate: 0.0010
# Epoch 17/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 184s 72ms/step - AUC: 0.9606 - Precision: 0.8336 - Recall: 0.8248 - accuracy: 0.8285 - loss: 0.8462 - val_AUC: 0.9886 - val_Precision: 0.9203 - val_Recall: 0.9138 - val_accuracy: 0.9157 - val_loss: 0.2996 - learning_rate: 0.0010
# Epoch 18/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 182s 72ms/step - AUC: 0.9816 - Precision: 0.8869 - Recall: 0.8756 - accuracy: 0.8802 - loss: 0.4504 - val_AUC: 0.9812 - val_Precision: 0.8735 - val_Recall: 0.8594 - val_accuracy: 0.8654 - val_loss: 0.7226 - learning_rate: 0.0010
# Epoch 19/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 183s 72ms/step - AUC: 0.9811 - Precision: 0.8781 - Recall: 0.8624 - accuracy: 0.8699 - loss: 0.4629 - val_AUC: 0.9311 - val_Precision: 0.8141 - val_Recall: 0.8118 - val_accuracy: 0.8122 - val_loss: 1.5600 - learning_rate: 0.0010
# Epoch 20/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 184s 73ms/step - AUC: 0.9712 - Precision: 0.8599 - Recall: 0.8498 - accuracy: 0.8542 - loss: 0.6385 - val_AUC: 0.9768 - val_Precision: 0.8886 - val_Recall: 0.8854 - val_accuracy: 0.8874 - val_loss: 0.5382 - learning_rate: 0.0010
# Epoch 21/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 186s 73ms/step - AUC: 0.9830 - Precision: 0.8895 - Recall: 0.8760 - accuracy: 0.8810 - loss: 0.4295 - val_AUC: 0.9888 - val_Precision: 0.9158 - val_Recall: 0.9075 - val_accuracy: 0.9098 - val_loss: 0.3127 - learning_rate: 0.0010
# Epoch 22/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - AUC: 0.9880 - Precision: 0.9094 - Recall: 0.8983 - accuracy: 0.9034 - loss: 0.3237
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 187s 74ms/step - AUC: 0.9880 - Precision: 0.9094 - Recall: 0.8983 - accuracy: 0.9034 - loss: 0.3237 - val_AUC: 0.9874 - val_Precision: 0.9090 - val_Recall: 0.9004 - val_accuracy: 0.9055 - val_loss: 0.3369 - learning_rate: 0.0010
# Epoch 23/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 189s 75ms/step - AUC: 0.9944 - Precision: 0.9392 - Recall: 0.9299 - accuracy: 0.9339 - loss: 0.1990 - val_AUC: 0.9958 - val_Precision: 0.9437 - val_Recall: 0.9374 - val_accuracy: 0.9406 - val_loss: 0.1787 - learning_rate: 1.0000e-04
# Epoch 24/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 192s 76ms/step - AUC: 0.9967 - Precision: 0.9497 - Recall: 0.9413 - accuracy: 0.9459 - loss: 0.1616 - val_AUC: 0.9956 - val_Precision: 0.9461 - val_Recall: 0.9394 - val_accuracy: 0.9417 - val_loss: 0.1713 - learning_rate: 1.0000e-04
# Epoch 25/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 195s 77ms/step - AUC: 0.9972 - Precision: 0.9535 - Recall: 0.9461 - accuracy: 0.9502 - loss: 0.1485 - val_AUC: 0.9963 - val_Precision: 0.9484 - val_Recall: 0.9413 - val_accuracy: 0.9433 - val_loss: 0.1591 - learning_rate: 1.0000e-04
# Epoch 26/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 196s 77ms/step - AUC: 0.9975 - Precision: 0.9550 - Recall: 0.9469 - accuracy: 0.9516 - loss: 0.1477 - val_AUC: 0.9966 - val_Precision: 0.9502 - val_Recall: 0.9457 - val_accuracy: 0.9476 - val_loss: 0.1568 - learning_rate: 1.0000e-04
# Epoch 27/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 197s 78ms/step - AUC: 0.9978 - Precision: 0.9573 - Recall: 0.9517 - accuracy: 0.9551 - loss: 0.1324 - val_AUC: 0.9952 - val_Precision: 0.9498 - val_Recall: 0.9457 - val_accuracy: 0.9476 - val_loss: 0.1935 - learning_rate: 1.0000e-04
# Epoch 28/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 198s 78ms/step - AUC: 0.9979 - Precision: 0.9570 - Recall: 0.9522 - accuracy: 0.9543 - loss: 0.1299 - val_AUC: 0.9967 - val_Precision: 0.9553 - val_Recall: 0.9500 - val_accuracy: 0.9535 - val_loss: 0.1437 - learning_rate: 1.0000e-04
# Epoch 29/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 199s 79ms/step - AUC: 0.9981 - Precision: 0.9598 - Recall: 0.9545 - accuracy: 0.9568 - loss: 0.1245 - val_AUC: 0.9968 - val_Precision: 0.9498 - val_Recall: 0.9453 - val_accuracy: 0.9476 - val_loss: 0.1615 - learning_rate: 1.0000e-04
# Epoch 30/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 200s 79ms/step - AUC: 0.9978 - Precision: 0.9610 - Recall: 0.9554 - accuracy: 0.9579 - loss: 0.1258 - val_AUC: 0.9963 - val_Precision: 0.9560 - val_Recall: 0.9488 - val_accuracy: 0.9516 - val_loss: 0.1469 - learning_rate: 1.0000e-04
# Epoch 31/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 202s 80ms/step - AUC: 0.9977 - Precision: 0.9626 - Recall: 0.9560 - accuracy: 0.9592 - loss: 0.1224 - val_AUC: 0.9973 - val_Precision: 0.9569 - val_Recall: 0.9524 - val_accuracy: 0.9535 - val_loss: 0.1338 - learning_rate: 1.0000e-04
# Epoch 32/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 203s 80ms/step - AUC: 0.9977 - Precision: 0.9638 - Recall: 0.9585 - accuracy: 0.9613 - loss: 0.1212 - val_AUC: 0.9972 - val_Precision: 0.9561 - val_Recall: 0.9508 - val_accuracy: 0.9543 - val_loss: 0.1400 - learning_rate: 1.0000e-04
# Epoch 33/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 204s 81ms/step - AUC: 0.9983 - Precision: 0.9610 - Recall: 0.9562 - accuracy: 0.9588 - loss: 0.1195 - val_AUC: 0.9975 - val_Precision: 0.9593 - val_Recall: 0.9547 - val_accuracy: 0.9563 - val_loss: 0.1337 - learning_rate: 1.0000e-04
# Epoch 34/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 205s 81ms/step - AUC: 0.9983 - Precision: 0.9626 - Recall: 0.9578 - accuracy: 0.9601 - loss: 0.1150 - val_AUC: 0.9967 - val_Precision: 0.9530 - val_Recall: 0.9492 - val_accuracy: 0.9512 - val_loss: 0.1466 - learning_rate: 1.0000e-04
# Epoch 35/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 206s 81ms/step - AUC: 0.9983 - Precision: 0.9647 - Recall: 0.9601 - accuracy: 0.9626 - loss: 0.1088 - val_AUC: 0.9965 - val_Precision: 0.9494 - val_Recall: 0.9457 - val_accuracy: 0.9480 - val_loss: 0.1538 - learning_rate: 1.0000e-04
# Epoch 36/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 207s 82ms/step - AUC: 0.9983 - Precision: 0.9625 - Recall: 0.9578 - accuracy: 0.9603 - loss: 0.1144 - val_AUC: 0.9961 - val_Precision: 0.9608 - val_Recall: 0.9563 - val_accuracy: 0.9587 - val_loss: 0.1347 - learning_rate: 1.0000e-04
# Epoch 37/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 209s 83ms/step - AUC: 0.9983 - Precision: 0.9666 - Recall: 0.9620 - accuracy: 0.9641 - loss: 0.1079 - val_AUC: 0.9974 - val_Precision: 0.9596 - val_Recall: 0.9547 - val_accuracy: 0.9563 - val_loss: 0.1364 - learning_rate: 1.0000e-04
# Epoch 38/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - AUC: 0.9982 - Precision: 0.9637 - Recall: 0.9592 - accuracy: 0.9610 - loss: 0.1106
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 210s 83ms/step - AUC: 0.9982 - Precision: 0.9637 - Recall: 0.9592 - accuracy: 0.9610 - loss: 0.1106 - val_AUC: 0.9974 - val_Precision: 0.9581 - val_Recall: 0.9543 - val_accuracy: 0.9555 - val_loss: 0.1342 - learning_rate: 1.0000e-04
# Epoch 39/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 211s 83ms/step - AUC: 0.9985 - Precision: 0.9687 - Recall: 0.9648 - accuracy: 0.9668 - loss: 0.0959 - val_AUC: 0.9976 - val_Precision: 0.9593 - val_Recall: 0.9559 - val_accuracy: 0.9579 - val_loss: 0.1215 - learning_rate: 1.0000e-05
# Epoch 40/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 212s 84ms/step - AUC: 0.9987 - Precision: 0.9685 - Recall: 0.9645 - accuracy: 0.9664 - loss: 0.0963 - val_AUC: 0.9971 - val_Precision: 0.9601 - val_Recall: 0.9567 - val_accuracy: 0.9579 - val_loss: 0.1300 - learning_rate: 1.0000e-05
# Epoch 41/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 214s 84ms/step - AUC: 0.9985 - Precision: 0.9701 - Recall: 0.9653 - accuracy: 0.9676 - loss: 0.0978 - val_AUC: 0.9973 - val_Precision: 0.9609 - val_Recall: 0.9583 - val_accuracy: 0.9602 - val_loss: 0.1254 - learning_rate: 1.0000e-05
# Epoch 42/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 216s 85ms/step - AUC: 0.9987 - Precision: 0.9701 - Recall: 0.9655 - accuracy: 0.9678 - loss: 0.0913 - val_AUC: 0.9978 - val_Precision: 0.9618 - val_Recall: 0.9602 - val_accuracy: 0.9606 - val_loss: 0.1196 - learning_rate: 1.0000e-05
# Epoch 43/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 216s 85ms/step - AUC: 0.9989 - Precision: 0.9692 - Recall: 0.9649 - accuracy: 0.9673 - loss: 0.0948 - val_AUC: 0.9979 - val_Precision: 0.9621 - val_Recall: 0.9606 - val_accuracy: 0.9614 - val_loss: 0.1187 - learning_rate: 1.0000e-05
# Epoch 44/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 217s 86ms/step - AUC: 0.9988 - Precision: 0.9687 - Recall: 0.9646 - accuracy: 0.9672 - loss: 0.0958 - val_AUC: 0.9977 - val_Precision: 0.9617 - val_Recall: 0.9591 - val_accuracy: 0.9610 - val_loss: 0.1237 - learning_rate: 1.0000e-05
# Epoch 45/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 220s 87ms/step - AUC: 0.9986 - Precision: 0.9701 - Recall: 0.9659 - accuracy: 0.9677 - loss: 0.0961 - val_AUC: 0.9970 - val_Precision: 0.9597 - val_Recall: 0.9563 - val_accuracy: 0.9575 - val_loss: 0.1299 - learning_rate: 1.0000e-05
# Epoch 46/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 220s 87ms/step - AUC: 0.9986 - Precision: 0.9665 - Recall: 0.9620 - accuracy: 0.9646 - loss: 0.1028 - val_AUC: 0.9975 - val_Precision: 0.9633 - val_Recall: 0.9602 - val_accuracy: 0.9614 - val_loss: 0.1215 - learning_rate: 1.0000e-05
# Epoch 47/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 222s 87ms/step - AUC: 0.9985 - Precision: 0.9659 - Recall: 0.9605 - accuracy: 0.9634 - loss: 0.1025 - val_AUC: 0.9979 - val_Precision: 0.9625 - val_Recall: 0.9591 - val_accuracy: 0.9614 - val_loss: 0.1236 - learning_rate: 1.0000e-05
# Epoch 48/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - AUC: 0.9989 - Precision: 0.9718 - Recall: 0.9678 - accuracy: 0.9694 - loss: 0.0957
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 222s 88ms/step - AUC: 0.9989 - Precision: 0.9718 - Recall: 0.9678 - accuracy: 0.9694 - loss: 0.0957 - val_AUC: 0.9979 - val_Precision: 0.9628 - val_Recall: 0.9591 - val_accuracy: 0.9598 - val_loss: 0.1221 - learning_rate: 1.0000e-05
# Epoch 49/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 224s 88ms/step - AUC: 0.9986 - Precision: 0.9702 - Recall: 0.9657 - accuracy: 0.9677 - loss: 0.0941 - val_AUC: 0.9977 - val_Precision: 0.9589 - val_Recall: 0.9551 - val_accuracy: 0.9571 - val_loss: 0.1243 - learning_rate: 1.0000e-06
# Epoch 50/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 226s 89ms/step - AUC: 0.9987 - Precision: 0.9686 - Recall: 0.9644 - accuracy: 0.9661 - loss: 0.0954 - val_AUC: 0.9978 - val_Precision: 0.9597 - val_Recall: 0.9555 - val_accuracy: 0.9575 - val_loss: 0.1265 - learning_rate: 1.0000e-06

# %%
model.save('all_models/EfficientNetV2B0.keras')

# %%
model.evaluate(test_generator)
# Out:
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - AUC: 0.9977 - Precision: 0.9792 - Recall: 0.9776 - accuracy: 0.9789 - loss: 0.0697
# [0.08279621601104736,
#  0.9753617644309998,
#  0.9757148623466492,
#  0.974188506603241,
#  0.9978526830673218]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.title("Learning curve", fontsize=16)
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend()
plt.savefig('learning_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Accuracy", fontsize=16)
plt.plot(history.history["accuracy"], label="Accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('accuracy_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Loss", fontsize=16)
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('loss_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Precision", fontsize=16)
plt.plot(history.history["Precision"], label="precision")
plt.plot(history.history["val_Precision"], label="val_precision")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('precision_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Recall", fontsize=16)
plt.plot(history.history["Recall"], label="recall")
plt.plot(history.history["val_Recall"], label="val_recall")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('recall_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation AUC", fontsize=16)
plt.plot(history.history["AUC"], label="AUC")
plt.plot(history.history["val_AUC"], label="val_AUC")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('auc_curve.pdf')

# %%
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step

# %%
# Binarize true labels
y_true_bin = label_binarize(y_true, classes=list(range(len(class_names))))

plt.figure(figsize=(10, 8))
for i in range(len(class_names)):
    precision, recall, _ = precision_recall_curve(
        y_true_bin[:, i], y_pred_probs[:, i])
    plt.plot(recall, precision, lw=2, label=f'{class_names[i]}')

plt.xlabel('Recall', fontsize=14)
plt.ylabel('Precision', fontsize=14)
plt.title('Precision-Recall Curve', fontsize=16)
plt.legend(loc='best')
plt.grid(True)
plt.savefig('precision_recall_curve.pdf')
plt.show()

# %%
# ROC Curve
y_true_bin = label_binarize(y_true, classes=list(range(num_classes)))
fpr = dict()
tpr = dict()
roc_auc = dict()

plt.figure(figsize=(10, 8))
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    plt.plot(fpr[i], tpr[i],
             label=f'{class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve', fontsize=16)
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.legend(loc='lower right')
plt.grid()
plt.savefig('roc_curve.pdf')
plt.show()

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img('/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test/CSR/csr_train_2348.jpg',target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,axis=1)
if a==0:
      op="AMD"   
elif a==1:
    op='CNV'
elif a==2:
    op='CSR'
elif a==3:
    op='DME'
elif a==4:
    op='DR'
elif a==5:
    op='DRUSEN'
elif a==6:
    op='MH'
else:
      op="Normal"
plt.imshow(img)
print("THE UPLOADED OCT IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# [[3.07771408e-08 5.04370190e-09 9.99999881e-01 1.06339715e-10
#   5.51065646e-08 1.85511138e-11 2.14694396e-08 1.05009251e-10]]
# THE UPLOADED OCT IMAGE IS: CSR

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img('/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test/NORMAL/no_2497093_3.jpg',target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,axis=1)
if a==0:
      op="AMD"   
elif a==1:
    op='CNV'
elif a==2:
    op='CSR'
elif a==3:
    op='DME'
elif a==4:
    op='DR'
elif a==5:
    op='DRUSEN'
elif a==6:
    op='MH'
else:
      op="Normal"
plt.imshow(img)
print("THE UPLOADED OCT IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[7.5859814e-03 2.7519143e-06 1.1632651e-08 7.0983538e-04 4.5177200e-09
#   5.1814699e-05 1.4531872e-08 9.9164963e-01]]
# THE UPLOADED OCT IMAGE IS: Normal

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Get true labels
y_true = validation_generator.classes

# Predict probabilities
y_pred_prob = model.predict(validation_generator)

# Convert probabilities to class indices
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 318/318 ━━━━━━━━━━━━━━━━━━━━ 20s 64ms/step

# %%
class_labels = list(validation_generator.class_indices.keys())

# %%
cm = confusion_matrix(y_true, y_pred)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("EfficientNetB3 Confusion Matrix", fontsize=16)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.show()
plt.savefig('confusion_matrix.pdf')

# %%
cm_normalized = confusion_matrix(y_true, y_pred, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("Normalized Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report


report = classification_report(y_true, y_pred, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          AMD       0.99      0.99      0.99       436
#          CNV       0.95      0.88      0.91       299
#          CSR       1.00      1.00      1.00       299
#          DME       0.93      0.96      0.94       314
#           DR       1.00      1.00      1.00       299
#       DRUSEN       0.89      0.91      0.90       299
#           MH       1.00      1.00      1.00       273
#       NORMAL       0.92      0.93      0.93       321
#
#     accuracy                           0.96      2540
#    macro avg       0.96      0.96      0.96      2540
# weighted avg       0.96      0.96      0.96      2540

# %% [markdown]
# ## Inference Time

# %%
import time
import numpy as np

# Assuming 'model' is your trained Keras model
# Assuming 'validation_generator' or a similar data source is available

# --- Prepare your inference data ---
# Get one batch for inference timing.
# Make sure validation_generator is properly initialized and can yield a batch.
# If your generator shuffles, reset it for consistent batch content if needed.
validation_generator.reset()
X_inference_batch, _ = next(validation_generator) # Use next() to get a single batch

print(f"Shape of inference batch: {X_inference_batch.shape}")
print(f"Batch size: {X_inference_batch.shape[0]}")

# --- 1. Warm-up runs (recommended) ---
print("\nPerforming warm-up runs...")
for _ in range(5): # Run 5 warm-up predictions
    _ = model.predict(X_inference_batch, verbose=0)
print("Warm-up complete.")

# --- 2. Measure inference time for a single batch (per step) ---
num_measurements = 100 # Number of times to repeat the measurement for averaging
inference_times_sec_per_step = []

print(f"\nMeasuring inference time over {num_measurements} repetitions...")
for _ in range(num_measurements):
    start_time = time.time()
    _ = model.predict(X_inference_batch, verbose=0) # Set verbose=0 to suppress progress bar
    end_time = time.time()
    inference_times_sec_per_step.append(end_time - start_time)

# Calculate average time per step in seconds
average_inference_time_sec_per_step = np.mean(inference_times_sec_per_step)
std_inference_time_sec_per_step = np.std(inference_times_sec_per_step)

# Convert to milliseconds per step
average_inference_time_ms_per_step = average_inference_time_sec_per_step * 1000
std_inference_time_ms_per_step = std_inference_time_sec_per_step * 1000

print(f"\nAverage inference time per step (batch size {X_inference_batch.shape[0]}):")
print(f"  {average_inference_time_ms_per_step:.4f} ms/step (Std Dev: {std_inference_time_ms_per_step:.4f} ms/step)")

# Optional: Calculate ms/sample if desired
samples_in_batch = X_inference_batch.shape[0]
if samples_in_batch > 0:
    average_inference_time_ms_per_sample = average_inference_time_ms_per_step / samples_in_batch
    print(f"  {average_inference_time_ms_per_sample:.4f} ms/sample")

# --- Example for total inference time over the whole validation set ---
# If you want to know the ms/step for the entire generator, you would need to
# divide the total inference time by the number of steps (batches) in the generator.

print("\nMeasuring total inference time for the entire validation set...")
validation_generator.reset() # Reset generator for a full pass
num_validation_steps = len(validation_generator) # Get the total number of batches

overall_inference_start_time = time.time()
_ = model.predict(validation_generator, verbose=1) # verbose=1 to see progress
overall_inference_end_time = time.time()

total_validation_inference_time_sec = overall_inference_end_time - overall_inference_start_time
total_validation_inference_time_ms = total_validation_inference_time_sec * 1000

# Calculate average ms/step for the entire validation set pass
if num_validation_steps > 0:
    average_ms_per_step_full_pass = total_validation_inference_time_ms / num_validation_steps
    print(f"Total inference time for validation set: {total_validation_inference_time_ms:.2f} ms")
    print(f"Average ms/step over entire validation set ({num_validation_steps} steps): {average_ms_per_step_full_pass:.4f} ms/step")
else:
    print("Validation generator has no steps.")
# Out:
# Shape of inference batch: (8, 224, 224, 3)
# Batch size: 8
#
# Performing warm-up runs...
# Warm-up complete.
#
# Measuring inference time over 100 repetitions...
#
# Average inference time per step (batch size 8):
#   59.4580 ms/step (Std Dev: 2.3467 ms/step)
#   7.4322 ms/sample
#
# Measuring total inference time for the entire validation set...
# 318/318 ━━━━━━━━━━━━━━━━━━━━ 19s 59ms/step
# Total inference time for validation set: 18975.02 ms
# Average ms/step over entire validation set (318 steps): 59.6699 ms/step

# %%
history.history.keys()
# Out:
# dict_keys(['AUC', 'Precision', 'Recall', 'accuracy', 'loss', 'val_AUC', 'val_Precision', 'val_Recall', 'val_accuracy', 'val_loss', 'learning_rate'])

# %%
history.params
# Out:
# {'verbose': 'auto', 'epochs': 50, 'steps': 634}

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
print(tf.keras.__version__)
# Out:
# 3.9.2
