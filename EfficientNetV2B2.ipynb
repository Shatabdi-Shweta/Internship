# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import roc_curve, precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
# Out:
# 2025-05-22 17:24:06.934708: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747913047.049812    8975 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747913047.080807    8975 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747913047.348854    8975 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747913047.348908    8975 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747913047.348916    8975 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747913047.348934    8975 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-22 17:24:07.375167: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_path= '/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/train'
val_path='/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/val'
test_path='/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test'

# %%
train_datagen = image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
val_datagen= image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_datagen= image.ImageDataGenerator()

# %%
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=True,
    class_mode = 'categorical')
validation_generator = val_datagen.flow_from_directory(
    val_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=False,
    class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=False,
    class_mode = 'categorical'
)
# Out:
# Found 20263 images belonging to 8 classes.
# Found 2540 images belonging to 8 classes.
# Found 2557 images belonging to 8 classes.

# %%
class_names = list(train_generator.class_indices.keys())
num_classes = len(class_names)
print(class_names)
# Out:
# ['AMD', 'CNV', 'CSR', 'DME', 'DR', 'DRUSEN', 'MH', 'NORMAL']

# %%
image_size = (224, 224)
batch_size = 8

# Function to load and preprocess images
def load_and_preprocess_image(file_path):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, image_size)
    img = tf.image.convert_image_dtype(img, tf.float32) / 255.0
    return img

# Function to get image paths and labels from a directory
def get_image_paths_and_labels(data_dir):
    image_paths = []
    labels = []
    class_names = sorted(os.listdir(data_dir))
    class_indices = {class_name: i for i, class_name in enumerate(class_names)}
    for class_name in class_names:
        class_path = os.path.join(data_dir, class_name)
        for filename in os.listdir(class_path):
            if filename.endswith(('.jpg', '.jpeg', '.png')):  # Adjust based on your file types
                image_paths.append(os.path.join(class_path, filename))
                labels.append(class_indices[class_name])
    return image_paths, tf.one_hot(labels, depth=len(class_names)) # One-hot encode labels

# Create training dataset
train_image_paths, train_labels = get_image_paths_and_labels(train_path)
train_dataset = tf.data.Dataset.from_tensor_slices((train_image_paths, train_labels))
train_dataset = train_dataset.map(lambda path, label: (load_and_preprocess_image(path), label),
                                  num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(buffer_size=len(train_image_paths))
train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# Create validation dataset
validation_image_paths, validation_labels = get_image_paths_and_labels(test_path)
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_image_paths, validation_labels))
validation_dataset = validation_dataset.map(lambda path, label: (load_and_preprocess_image(path), label),
                                           num_parallel_calls=tf.data.AUTOTUNE)
validation_dataset = validation_dataset.batch(batch_size)
validation_dataset = validation_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# I0000 00:00:1747913051.369355    8975 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5616 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
from tensorflow.keras import Sequential, layers

# Load the pre-trained EfficientNetB3 model (excluding the top classification layer)
base_model = tf.keras.applications.EfficientNetV2B2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = True

# Create a new sequential model
model = Sequential()

# Add the EfficientNetB3 base model
model.add(base_model)

# Add the convolutional layers you defined
# model.add(layers.Conv2D(filters=8, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding="same"))
# model.add(layers.BatchNormalization())
# model.add(layers.MaxPool2D(pool_size=(3, 3)))

model.add(layers.Flatten())
model.add(layers.Dense(8, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetv2-b2 (Functional)  │ (None, 7, 7, 1408)     │     8,769,374 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 68992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │       551,944 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,321,318 (35.56 MB)
#  Trainable params: 9,239,030 (35.24 MB)
#  Non-trainable params: 82,288 (321.44 KB)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.AdamW(),
              metrics=['accuracy','Precision','Recall','AUC'])

# %%
history = model.fit(
    train_generator,
    epochs=50,
    callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, mode='auto')],
    validation_data=validation_generator
    )
# Out:
# Epoch 1/50
# /home/nemo/.conda/envs/tf/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747913095.045222    9144 service.cc:152] XLA service 0x79b044003940 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747913095.045237    9144 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3050, Compute Capability 8.6
# 2025-05-22 17:24:56.165439: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747913100.479828    9144 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    2/2533 ━━━━━━━━━━━━━━━━━━━━ 2:23 57ms/step - AUC: 0.5985 - Precision: 0.2000 - Recall: 0.0625 - accuracy: 0.0625 - loss: 2.3976
# I0000 00:00:1747913134.247439    9144 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 314s 96ms/step - AUC: 0.8542 - Precision: 0.6266 - Recall: 0.6094 - accuracy: 0.6159 - loss: 2.7112 - val_AUC: 0.9491 - val_Precision: 0.8461 - val_Recall: 0.8417 - val_accuracy: 0.8433 - val_loss: 1.1261 - learning_rate: 0.0010
# Epoch 2/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 176s 69ms/step - AUC: 0.9376 - Precision: 0.8115 - Recall: 0.8069 - accuracy: 0.8088 - loss: 1.4114 - val_AUC: 0.9540 - val_Precision: 0.8583 - val_Recall: 0.8539 - val_accuracy: 0.8559 - val_loss: 1.2488 - learning_rate: 0.0010
# Epoch 3/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 176s 70ms/step - AUC: 0.9255 - Precision: 0.7672 - Recall: 0.7590 - accuracy: 0.7617 - loss: 1.5717 - val_AUC: 0.9365 - val_Precision: 0.8041 - val_Recall: 0.7965 - val_accuracy: 0.7980 - val_loss: 1.3260 - learning_rate: 0.0010
# Epoch 4/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 181s 72ms/step - AUC: 0.8687 - Precision: 0.6285 - Recall: 0.6106 - accuracy: 0.6196 - loss: 2.3665 - val_AUC: 0.9061 - val_Precision: 0.6677 - val_Recall: 0.6209 - val_accuracy: 0.6433 - val_loss: 1.4311 - learning_rate: 0.0010
# Epoch 5/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 176s 69ms/step - AUC: 0.8672 - Precision: 0.5823 - Recall: 0.5464 - accuracy: 0.5637 - loss: 2.0498 - val_AUC: 0.9309 - val_Precision: 0.7115 - val_Recall: 0.6768 - val_accuracy: 0.6949 - val_loss: 1.3836 - learning_rate: 0.0010
# Epoch 6/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 165s 65ms/step - AUC: 0.9192 - Precision: 0.6900 - Recall: 0.6624 - accuracy: 0.6735 - loss: 1.3760 - val_AUC: 0.9454 - val_Precision: 0.7638 - val_Recall: 0.7398 - val_accuracy: 0.7512 - val_loss: 1.0830 - learning_rate: 0.0010
# Epoch 7/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 165s 65ms/step - AUC: 0.9394 - Precision: 0.7356 - Recall: 0.7110 - accuracy: 0.7221 - loss: 1.1264 - val_AUC: 0.9757 - val_Precision: 0.8558 - val_Recall: 0.8409 - val_accuracy: 0.8457 - val_loss: 0.5867 - learning_rate: 0.0010
# Epoch 8/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 165s 65ms/step - AUC: 0.9321 - Precision: 0.7384 - Recall: 0.7201 - accuracy: 0.7282 - loss: 1.2525 - val_AUC: 0.9626 - val_Precision: 0.8239 - val_Recall: 0.7996 - val_accuracy: 0.8142 - val_loss: 0.8036 - learning_rate: 0.0010
# Epoch 9/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 166s 65ms/step - AUC: 0.9512 - Precision: 0.7802 - Recall: 0.7580 - accuracy: 0.7679 - loss: 0.9456 - val_AUC: 0.9738 - val_Precision: 0.8515 - val_Recall: 0.8354 - val_accuracy: 0.8417 - val_loss: 0.5954 - learning_rate: 0.0010
# Epoch 10/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 166s 65ms/step - AUC: 0.9449 - Precision: 0.7638 - Recall: 0.7401 - accuracy: 0.7502 - loss: 1.0243 - val_AUC: 0.9740 - val_Precision: 0.8627 - val_Recall: 0.8535 - val_accuracy: 0.8571 - val_loss: 0.5546 - learning_rate: 0.0010
# Epoch 11/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 166s 66ms/step - AUC: 0.9563 - Precision: 0.8004 - Recall: 0.7840 - accuracy: 0.7914 - loss: 0.8904 - val_AUC: 0.9789 - val_Precision: 0.8556 - val_Recall: 0.8256 - val_accuracy: 0.8413 - val_loss: 0.5275 - learning_rate: 0.0010
# Epoch 12/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 166s 66ms/step - AUC: 0.9666 - Precision: 0.8201 - Recall: 0.7948 - accuracy: 0.8076 - loss: 0.7030 - val_AUC: 0.9466 - val_Precision: 0.7592 - val_Recall: 0.7386 - val_accuracy: 0.7480 - val_loss: 0.9948 - learning_rate: 0.0010
# Epoch 13/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 167s 66ms/step - AUC: 0.9569 - Precision: 0.7940 - Recall: 0.7742 - accuracy: 0.7838 - loss: 0.8507 - val_AUC: 0.9696 - val_Precision: 0.8445 - val_Recall: 0.8315 - val_accuracy: 0.8366 - val_loss: 0.6465 - learning_rate: 0.0010
# Epoch 14/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 167s 66ms/step - AUC: 0.9701 - Precision: 0.8400 - Recall: 0.8251 - accuracy: 0.8317 - loss: 0.6771 - val_AUC: 0.9757 - val_Precision: 0.8670 - val_Recall: 0.8547 - val_accuracy: 0.8610 - val_loss: 0.7488 - learning_rate: 0.0010
# Epoch 15/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 168s 66ms/step - AUC: 0.9671 - Precision: 0.8344 - Recall: 0.8171 - accuracy: 0.8257 - loss: 0.7019 - val_AUC: 0.9656 - val_Precision: 0.8503 - val_Recall: 0.8339 - val_accuracy: 0.8429 - val_loss: 0.7608 - learning_rate: 0.0010
# Epoch 16/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 172s 68ms/step - AUC: 0.9657 - Precision: 0.8317 - Recall: 0.8176 - accuracy: 0.8235 - loss: 0.7196 - val_AUC: 0.9814 - val_Precision: 0.8820 - val_Recall: 0.8709 - val_accuracy: 0.8748 - val_loss: 0.4611 - learning_rate: 0.0010
# Epoch 17/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 182s 72ms/step - AUC: 0.9748 - Precision: 0.8509 - Recall: 0.8336 - accuracy: 0.8405 - loss: 0.5817 - val_AUC: 0.9877 - val_Precision: 0.9033 - val_Recall: 0.8933 - val_accuracy: 0.8988 - val_loss: 0.3624 - learning_rate: 0.0010
# Epoch 18/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 184s 73ms/step - AUC: 0.9826 - Precision: 0.8816 - Recall: 0.8650 - accuracy: 0.8713 - loss: 0.4381 - val_AUC: 0.9874 - val_Precision: 0.9107 - val_Recall: 0.8913 - val_accuracy: 0.8992 - val_loss: 0.3396 - learning_rate: 0.0010
# Epoch 19/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 185s 73ms/step - AUC: 0.9818 - Precision: 0.8799 - Recall: 0.8645 - accuracy: 0.8721 - loss: 0.4500 - val_AUC: 0.9889 - val_Precision: 0.9189 - val_Recall: 0.9102 - val_accuracy: 0.9138 - val_loss: 0.3012 - learning_rate: 0.0010
# Epoch 20/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 187s 74ms/step - AUC: 0.9857 - Precision: 0.8980 - Recall: 0.8860 - accuracy: 0.8908 - loss: 0.3792 - val_AUC: 0.9864 - val_Precision: 0.9078 - val_Recall: 0.8988 - val_accuracy: 0.9051 - val_loss: 0.3729 - learning_rate: 0.0010
# Epoch 21/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 188s 74ms/step - AUC: 0.9809 - Precision: 0.8804 - Recall: 0.8699 - accuracy: 0.8750 - loss: 0.4647 - val_AUC: 0.9701 - val_Precision: 0.8783 - val_Recall: 0.8697 - val_accuracy: 0.8720 - val_loss: 1.9434 - learning_rate: 0.0010
# Epoch 22/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 189s 75ms/step - AUC: 0.9888 - Precision: 0.9132 - Recall: 0.9023 - accuracy: 0.9068 - loss: 0.3121 - val_AUC: 0.9838 - val_Precision: 0.9119 - val_Recall: 0.9043 - val_accuracy: 0.9071 - val_loss: 0.3730 - learning_rate: 0.0010
# Epoch 23/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 191s 76ms/step - AUC: 0.9771 - Precision: 0.8680 - Recall: 0.8549 - accuracy: 0.8605 - loss: 0.5311 - val_AUC: 0.9865 - val_Precision: 0.9136 - val_Recall: 0.9071 - val_accuracy: 0.9091 - val_loss: 0.3473 - learning_rate: 0.0010
# Epoch 24/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - AUC: 0.9833 - Precision: 0.8942 - Recall: 0.8852 - accuracy: 0.8891 - loss: 0.4169
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 194s 77ms/step - AUC: 0.9833 - Precision: 0.8942 - Recall: 0.8852 - accuracy: 0.8891 - loss: 0.4169 - val_AUC: 0.9873 - val_Precision: 0.9075 - val_Recall: 0.9000 - val_accuracy: 0.9043 - val_loss: 0.3412 - learning_rate: 0.0010
# Epoch 25/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 197s 78ms/step - AUC: 0.9931 - Precision: 0.9256 - Recall: 0.9154 - accuracy: 0.9200 - loss: 0.2423 - val_AUC: 0.9943 - val_Precision: 0.9407 - val_Recall: 0.9311 - val_accuracy: 0.9362 - val_loss: 0.1975 - learning_rate: 1.0000e-04
# Epoch 26/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 197s 78ms/step - AUC: 0.9963 - Precision: 0.9441 - Recall: 0.9337 - accuracy: 0.9395 - loss: 0.1790 - val_AUC: 0.9957 - val_Precision: 0.9400 - val_Recall: 0.9319 - val_accuracy: 0.9358 - val_loss: 0.1917 - learning_rate: 1.0000e-04
# Epoch 27/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 198s 78ms/step - AUC: 0.9963 - Precision: 0.9452 - Recall: 0.9357 - accuracy: 0.9398 - loss: 0.1839 - val_AUC: 0.9962 - val_Precision: 0.9491 - val_Recall: 0.9402 - val_accuracy: 0.9449 - val_loss: 0.1690 - learning_rate: 1.0000e-04
# Epoch 28/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 198s 78ms/step - AUC: 0.9972 - Precision: 0.9509 - Recall: 0.9429 - accuracy: 0.9471 - loss: 0.1551 - val_AUC: 0.9955 - val_Precision: 0.9441 - val_Recall: 0.9378 - val_accuracy: 0.9413 - val_loss: 0.1750 - learning_rate: 1.0000e-04
# Epoch 29/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 201s 79ms/step - AUC: 0.9964 - Precision: 0.9496 - Recall: 0.9412 - accuracy: 0.9451 - loss: 0.1622 - val_AUC: 0.9965 - val_Precision: 0.9511 - val_Recall: 0.9413 - val_accuracy: 0.9469 - val_loss: 0.1710 - learning_rate: 1.0000e-04
# Epoch 30/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 202s 80ms/step - AUC: 0.9976 - Precision: 0.9543 - Recall: 0.9460 - accuracy: 0.9504 - loss: 0.1444 - val_AUC: 0.9974 - val_Precision: 0.9500 - val_Recall: 0.9421 - val_accuracy: 0.9441 - val_loss: 0.1596 - learning_rate: 1.0000e-04
# Epoch 31/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 202s 80ms/step - AUC: 0.9972 - Precision: 0.9518 - Recall: 0.9415 - accuracy: 0.9476 - loss: 0.1554 - val_AUC: 0.9971 - val_Precision: 0.9565 - val_Recall: 0.9520 - val_accuracy: 0.9547 - val_loss: 0.1406 - learning_rate: 1.0000e-04
# Epoch 32/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 203s 80ms/step - AUC: 0.9976 - Precision: 0.9536 - Recall: 0.9470 - accuracy: 0.9499 - loss: 0.1439 - val_AUC: 0.9964 - val_Precision: 0.9486 - val_Recall: 0.9445 - val_accuracy: 0.9461 - val_loss: 0.1552 - learning_rate: 1.0000e-04
# Epoch 33/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 205s 81ms/step - AUC: 0.9972 - Precision: 0.9542 - Recall: 0.9463 - accuracy: 0.9499 - loss: 0.1496 - val_AUC: 0.9963 - val_Precision: 0.9587 - val_Recall: 0.9504 - val_accuracy: 0.9551 - val_loss: 0.1520 - learning_rate: 1.0000e-04
# Epoch 34/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 208s 82ms/step - AUC: 0.9972 - Precision: 0.9573 - Recall: 0.9517 - accuracy: 0.9544 - loss: 0.1380 - val_AUC: 0.9977 - val_Precision: 0.9556 - val_Recall: 0.9500 - val_accuracy: 0.9528 - val_loss: 0.1464 - learning_rate: 1.0000e-04
# Epoch 35/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 208s 82ms/step - AUC: 0.9973 - Precision: 0.9581 - Recall: 0.9520 - accuracy: 0.9553 - loss: 0.1364 - val_AUC: 0.9970 - val_Precision: 0.9534 - val_Recall: 0.9496 - val_accuracy: 0.9516 - val_loss: 0.1425 - learning_rate: 1.0000e-04
# Epoch 36/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - AUC: 0.9978 - Precision: 0.9574 - Recall: 0.9503 - accuracy: 0.9535 - loss: 0.1339
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 210s 83ms/step - AUC: 0.9978 - Precision: 0.9574 - Recall: 0.9503 - accuracy: 0.9535 - loss: 0.1339 - val_AUC: 0.9964 - val_Precision: 0.9485 - val_Recall: 0.9421 - val_accuracy: 0.9445 - val_loss: 0.1597 - learning_rate: 1.0000e-04
# Epoch 37/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 210s 83ms/step - AUC: 0.9975 - Precision: 0.9585 - Recall: 0.9519 - accuracy: 0.9556 - loss: 0.1336 - val_AUC: 0.9976 - val_Precision: 0.9535 - val_Recall: 0.9520 - val_accuracy: 0.9528 - val_loss: 0.1392 - learning_rate: 1.0000e-05
# Epoch 38/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 211s 83ms/step - AUC: 0.9982 - Precision: 0.9608 - Recall: 0.9554 - accuracy: 0.9584 - loss: 0.1180 - val_AUC: 0.9971 - val_Precision: 0.9526 - val_Recall: 0.9492 - val_accuracy: 0.9508 - val_loss: 0.1462 - learning_rate: 1.0000e-05
# Epoch 39/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 213s 84ms/step - AUC: 0.9985 - Precision: 0.9611 - Recall: 0.9543 - accuracy: 0.9569 - loss: 0.1195 - val_AUC: 0.9972 - val_Precision: 0.9533 - val_Recall: 0.9488 - val_accuracy: 0.9504 - val_loss: 0.1408 - learning_rate: 1.0000e-05
# Epoch 40/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 213s 84ms/step - AUC: 0.9982 - Precision: 0.9632 - Recall: 0.9571 - accuracy: 0.9598 - loss: 0.1170 - val_AUC: 0.9970 - val_Precision: 0.9534 - val_Recall: 0.9496 - val_accuracy: 0.9520 - val_loss: 0.1426 - learning_rate: 1.0000e-05
# Epoch 41/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 214s 84ms/step - AUC: 0.9979 - Precision: 0.9606 - Recall: 0.9561 - accuracy: 0.9584 - loss: 0.1226 - val_AUC: 0.9974 - val_Precision: 0.9593 - val_Recall: 0.9551 - val_accuracy: 0.9571 - val_loss: 0.1302 - learning_rate: 1.0000e-05
# Epoch 42/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 216s 85ms/step - AUC: 0.9984 - Precision: 0.9636 - Recall: 0.9579 - accuracy: 0.9608 - loss: 0.1168 - val_AUC: 0.9979 - val_Precision: 0.9561 - val_Recall: 0.9508 - val_accuracy: 0.9535 - val_loss: 0.1316 - learning_rate: 1.0000e-05
# Epoch 43/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 217s 86ms/step - AUC: 0.9981 - Precision: 0.9628 - Recall: 0.9576 - accuracy: 0.9602 - loss: 0.1185 - val_AUC: 0.9969 - val_Precision: 0.9561 - val_Recall: 0.9528 - val_accuracy: 0.9547 - val_loss: 0.1377 - learning_rate: 1.0000e-05
# Epoch 44/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 219s 87ms/step - AUC: 0.9982 - Precision: 0.9620 - Recall: 0.9566 - accuracy: 0.9592 - loss: 0.1178 - val_AUC: 0.9969 - val_Precision: 0.9537 - val_Recall: 0.9492 - val_accuracy: 0.9516 - val_loss: 0.1459 - learning_rate: 1.0000e-05
# Epoch 45/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 221s 87ms/step - AUC: 0.9983 - Precision: 0.9642 - Recall: 0.9575 - accuracy: 0.9616 - loss: 0.1146 - val_AUC: 0.9972 - val_Precision: 0.9529 - val_Recall: 0.9484 - val_accuracy: 0.9508 - val_loss: 0.1458 - learning_rate: 1.0000e-05
# Epoch 46/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - AUC: 0.9982 - Precision: 0.9620 - Recall: 0.9564 - accuracy: 0.9585 - loss: 0.1211
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 223s 88ms/step - AUC: 0.9982 - Precision: 0.9620 - Recall: 0.9564 - accuracy: 0.9585 - loss: 0.1211 - val_AUC: 0.9977 - val_Precision: 0.9557 - val_Recall: 0.9512 - val_accuracy: 0.9539 - val_loss: 0.1344 - learning_rate: 1.0000e-05
# Epoch 47/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 225s 89ms/step - AUC: 0.9984 - Precision: 0.9644 - Recall: 0.9586 - accuracy: 0.9616 - loss: 0.1130 - val_AUC: 0.9969 - val_Precision: 0.9544 - val_Recall: 0.9480 - val_accuracy: 0.9496 - val_loss: 0.1491 - learning_rate: 1.0000e-06
# Epoch 48/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 226s 89ms/step - AUC: 0.9982 - Precision: 0.9622 - Recall: 0.9565 - accuracy: 0.9593 - loss: 0.1190 - val_AUC: 0.9972 - val_Precision: 0.9581 - val_Recall: 0.9535 - val_accuracy: 0.9563 - val_loss: 0.1402 - learning_rate: 1.0000e-06
# Epoch 49/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 227s 89ms/step - AUC: 0.9983 - Precision: 0.9616 - Recall: 0.9552 - accuracy: 0.9578 - loss: 0.1185 - val_AUC: 0.9970 - val_Precision: 0.9537 - val_Recall: 0.9492 - val_accuracy: 0.9504 - val_loss: 0.1419 - learning_rate: 1.0000e-06
# Epoch 50/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 227s 90ms/step - AUC: 0.9983 - Precision: 0.9625 - Recall: 0.9577 - accuracy: 0.9597 - loss: 0.1163 - val_AUC: 0.9977 - val_Precision: 0.9557 - val_Recall: 0.9508 - val_accuracy: 0.9528 - val_loss: 0.1367 - learning_rate: 1.0000e-06

# %%
model.save('all_models/EfficientNetV2B2.keras')

# %%
model.evaluate(test_generator)
# Out:
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - AUC: 0.9980 - Precision: 0.9685 - Recall: 0.9664 - accuracy: 0.9671 - loss: 0.0904
# [0.10348212718963623,
#  0.9644114375114441,
#  0.9658689498901367,
#  0.962847113609314,
#  0.9978029131889343]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.title("Learning curve", fontsize=16)
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend()
plt.savefig('learning_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Accuracy", fontsize=16)
plt.plot(history.history["accuracy"], label="Accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('accuracy_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Loss", fontsize=16)
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('loss_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Precision", fontsize=16)
plt.plot(history.history["Precision"], label="precision")
plt.plot(history.history["val_Precision"], label="val_precision")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('precision_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Recall", fontsize=16)
plt.plot(history.history["Recall"], label="recall")
plt.plot(history.history["val_Recall"], label="val_recall")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('recall_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation AUC", fontsize=16)
plt.plot(history.history["AUC"], label="AUC")
plt.plot(history.history["val_AUC"], label="val_AUC")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('auc_curve.pdf')

# %%
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step

# %%
# Binarize true labels
y_true_bin = label_binarize(y_true, classes=list(range(len(class_names))))

plt.figure(figsize=(10, 8))
for i in range(len(class_names)):
    precision, recall, _ = precision_recall_curve(
        y_true_bin[:, i], y_pred_probs[:, i])
    plt.plot(recall, precision, lw=2, label=f'{class_names[i]}')

plt.xlabel('Recall', fontsize=14)
plt.ylabel('Precision', fontsize=14)
plt.title('Precision-Recall Curve', fontsize=16)
plt.legend(loc='best')
plt.grid(True)
plt.savefig('precision_recall_curve.pdf')
plt.show()

# %%
# ROC Curve
y_true_bin = label_binarize(y_true, classes=list(range(num_classes)))
fpr = dict()
tpr = dict()
roc_auc = dict()

plt.figure(figsize=(10, 8))
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    plt.plot(fpr[i], tpr[i],
             label=f'{class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve', fontsize=16)
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.legend(loc='lower right')
plt.grid()
plt.savefig('roc_curve.pdf')
plt.show()

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img('/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test/CSR/csr_train_2348.jpg',target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,axis=1)
if a==0:
      op="AMD"   
elif a==1:
    op='CNV'
elif a==2:
    op='CSR'
elif a==3:
    op='DME'
elif a==4:
    op='DR'
elif a==5:
    op='DRUSEN'
elif a==6:
    op='MH'
else:
      op="Normal"
plt.imshow(img)
print("THE UPLOADED OCT IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# [[6.9352232e-11 1.1816939e-10 1.0000000e+00 2.5686815e-13 1.3418125e-08
#   3.2554383e-14 8.3906160e-10 4.8272871e-13]]
# THE UPLOADED OCT IMAGE IS: CSR

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img('/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test/NORMAL/no_2497093_3.jpg',target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,axis=1)
if a==0:
      op="AMD"   
elif a==1:
    op='CNV'
elif a==2:
    op='CSR'
elif a==3:
    op='DME'
elif a==4:
    op='DR'
elif a==5:
    op='DRUSEN'
elif a==6:
    op='MH'
else:
      op="Normal"
plt.imshow(img)
print("THE UPLOADED OCT IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[1.3458251e-03 3.3727878e-09 5.1502150e-11 2.4850393e-05 2.1091989e-10
#   9.0302037e-06 3.1988644e-12 9.9862027e-01]]
# THE UPLOADED OCT IMAGE IS: Normal

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Get true labels
y_true = validation_generator.classes

# Predict probabilities
y_pred_prob = model.predict(validation_generator)

# Convert probabilities to class indices
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 318/318 ━━━━━━━━━━━━━━━━━━━━ 22s 68ms/step

# %%
class_labels = list(validation_generator.class_indices.keys())

# %%
cm = confusion_matrix(y_true, y_pred)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("EfficientNetB3 Confusion Matrix", fontsize=16)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.show()
plt.savefig('confusion_matrix.pdf')

# %%
cm_normalized = confusion_matrix(y_true, y_pred, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("Normalized Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report


report = classification_report(y_true, y_pred, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          AMD       1.00      0.98      0.99       436
#          CNV       0.92      0.86      0.89       299
#          CSR       0.99      1.00      1.00       299
#          DME       0.91      0.91      0.91       314
#           DR       1.00      0.99      0.99       299
#       DRUSEN       0.90      0.90      0.90       299
#           MH       0.99      0.99      0.99       273
#       NORMAL       0.89      0.94      0.92       321
#
#     accuracy                           0.95      2540
#    macro avg       0.95      0.95      0.95      2540
# weighted avg       0.95      0.95      0.95      2540

# %% [markdown]
# ## Inference Time

# %%
import time
import numpy as np

# Assuming 'model' is your trained Keras model
# Assuming 'validation_generator' or a similar data source is available

# --- Prepare your inference data ---
# Get one batch for inference timing.
# Make sure validation_generator is properly initialized and can yield a batch.
# If your generator shuffles, reset it for consistent batch content if needed.
validation_generator.reset()
X_inference_batch, _ = next(validation_generator) # Use next() to get a single batch

print(f"Shape of inference batch: {X_inference_batch.shape}")
print(f"Batch size: {X_inference_batch.shape[0]}")

# --- 1. Warm-up runs (recommended) ---
print("\nPerforming warm-up runs...")
for _ in range(5): # Run 5 warm-up predictions
    _ = model.predict(X_inference_batch, verbose=0)
print("Warm-up complete.")

# --- 2. Measure inference time for a single batch (per step) ---
num_measurements = 100 # Number of times to repeat the measurement for averaging
inference_times_sec_per_step = []

print(f"\nMeasuring inference time over {num_measurements} repetitions...")
for _ in range(num_measurements):
    start_time = time.time()
    _ = model.predict(X_inference_batch, verbose=0) # Set verbose=0 to suppress progress bar
    end_time = time.time()
    inference_times_sec_per_step.append(end_time - start_time)

# Calculate average time per step in seconds
average_inference_time_sec_per_step = np.mean(inference_times_sec_per_step)
std_inference_time_sec_per_step = np.std(inference_times_sec_per_step)

# Convert to milliseconds per step
average_inference_time_ms_per_step = average_inference_time_sec_per_step * 1000
std_inference_time_ms_per_step = std_inference_time_sec_per_step * 1000

print(f"\nAverage inference time per step (batch size {X_inference_batch.shape[0]}):")
print(f"  {average_inference_time_ms_per_step:.4f} ms/step (Std Dev: {std_inference_time_ms_per_step:.4f} ms/step)")

# Optional: Calculate ms/sample if desired
samples_in_batch = X_inference_batch.shape[0]
if samples_in_batch > 0:
    average_inference_time_ms_per_sample = average_inference_time_ms_per_step / samples_in_batch
    print(f"  {average_inference_time_ms_per_sample:.4f} ms/sample")

# --- Example for total inference time over the whole validation set ---
# If you want to know the ms/step for the entire generator, you would need to
# divide the total inference time by the number of steps (batches) in the generator.

print("\nMeasuring total inference time for the entire validation set...")
validation_generator.reset() # Reset generator for a full pass
num_validation_steps = len(validation_generator) # Get the total number of batches

overall_inference_start_time = time.time()
_ = model.predict(validation_generator, verbose=1) # verbose=1 to see progress
overall_inference_end_time = time.time()

total_validation_inference_time_sec = overall_inference_end_time - overall_inference_start_time
total_validation_inference_time_ms = total_validation_inference_time_sec * 1000

# Calculate average ms/step for the entire validation set pass
if num_validation_steps > 0:
    average_ms_per_step_full_pass = total_validation_inference_time_ms / num_validation_steps
    print(f"Total inference time for validation set: {total_validation_inference_time_ms:.2f} ms")
    print(f"Average ms/step over entire validation set ({num_validation_steps} steps): {average_ms_per_step_full_pass:.4f} ms/step")
else:
    print("Validation generator has no steps.")
# Out:
# Shape of inference batch: (8, 224, 224, 3)
# Batch size: 8
#
# Performing warm-up runs...
# Warm-up complete.
#
# Measuring inference time over 100 repetitions...
#
# Average inference time per step (batch size 8):
#   62.6887 ms/step (Std Dev: 1.9347 ms/step)
#   7.8361 ms/sample
#
# Measuring total inference time for the entire validation set...
# 318/318 ━━━━━━━━━━━━━━━━━━━━ 20s 63ms/step
# Total inference time for validation set: 20361.28 ms
# Average ms/step over entire validation set (318 steps): 64.0292 ms/step

# %%
history.history.keys()
# Out:
# dict_keys(['AUC', 'Precision', 'Recall', 'accuracy', 'loss', 'val_AUC', 'val_Precision', 'val_Recall', 'val_accuracy', 'val_loss', 'learning_rate'])

# %%
history.params
# Out:
# {'verbose': 'auto', 'epochs': 50, 'steps': 634}

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
print(tf.keras.__version__)
# Out:
# 3.9.2
