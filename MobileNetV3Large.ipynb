# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import roc_curve, precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
# Out:
# 2025-05-23 01:14:30.918075: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747941271.043959  126080 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747941271.077049  126080 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747941271.365509  126080 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747941271.365583  126080 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747941271.365584  126080 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747941271.365585  126080 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-23 01:14:31.396685: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_path= '/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/train'
val_path='/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/val'
test_path='/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test'

# %%
train_datagen = image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
val_datagen= image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_datagen= image.ImageDataGenerator()

# %%
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=True,
    class_mode = 'categorical')
validation_generator = val_datagen.flow_from_directory(
    val_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=False,
    class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size = (224,224),
    batch_size = 8,
    shuffle=False,
    class_mode = 'categorical'
)
# Out:
# Found 20263 images belonging to 8 classes.
# Found 2540 images belonging to 8 classes.
# Found 2557 images belonging to 8 classes.

# %%
class_names = list(train_generator.class_indices.keys())
num_classes = len(class_names)
print(class_names)
# Out:
# ['AMD', 'CNV', 'CSR', 'DME', 'DR', 'DRUSEN', 'MH', 'NORMAL']

# %%
image_size = (224, 224)
batch_size = 8

# Function to load and preprocess images
def load_and_preprocess_image(file_path):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, image_size)
    img = tf.image.convert_image_dtype(img, tf.float32) / 255.0
    return img

# Function to get image paths and labels from a directory
def get_image_paths_and_labels(data_dir):
    image_paths = []
    labels = []
    class_names = sorted(os.listdir(data_dir))
    class_indices = {class_name: i for i, class_name in enumerate(class_names)}
    for class_name in class_names:
        class_path = os.path.join(data_dir, class_name)
        for filename in os.listdir(class_path):
            if filename.endswith(('.jpg', '.jpeg', '.png')):  # Adjust based on your file types
                image_paths.append(os.path.join(class_path, filename))
                labels.append(class_indices[class_name])
    return image_paths, tf.one_hot(labels, depth=len(class_names)) # One-hot encode labels

# Create training dataset
train_image_paths, train_labels = get_image_paths_and_labels(train_path)
train_dataset = tf.data.Dataset.from_tensor_slices((train_image_paths, train_labels))
train_dataset = train_dataset.map(lambda path, label: (load_and_preprocess_image(path), label),
                                  num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(buffer_size=len(train_image_paths))
train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# Create validation dataset
validation_image_paths, validation_labels = get_image_paths_and_labels(test_path)
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_image_paths, validation_labels))
validation_dataset = validation_dataset.map(lambda path, label: (load_and_preprocess_image(path), label),
                                           num_parallel_calls=tf.data.AUTOTUNE)
validation_dataset = validation_dataset.batch(batch_size)
validation_dataset = validation_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# I0000 00:00:1747941275.202638  126080 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5662 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
from tensorflow.keras import Sequential, layers

# Load the pre-trained EfficientNetB3 model (excluding the top classification layer)
base_model = tf.keras.applications.MobileNetV3Large(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = True

# Create a new sequential model
model = Sequential()

# Add the EfficientNetB3 base model
model.add(base_model)

# Add the convolutional layers you defined
# model.add(layers.Conv2D(filters=8, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding="same"))
# model.add(layers.BatchNormalization())
# model.add(layers.MaxPool2D(pool_size=(3, 3)))

model.add(layers.Flatten())
model.add(layers.Dense(8, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ MobileNetV3Large (Functional)   │ (None, 7, 7, 960)      │     2,996,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 47040)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │       376,328 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,372,680 (12.87 MB)
#  Trainable params: 3,348,280 (12.77 MB)
#  Non-trainable params: 24,400 (95.31 KB)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.AdamW(),
              metrics=['accuracy','Precision','Recall','AUC'])

# %%
history = model.fit(
    train_generator,
    epochs=50,
    callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, mode='auto')],
    validation_data=validation_generator
    )
# Out:
# Epoch 1/50
# /home/nemo/.conda/envs/tf/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747941298.675228  126242 service.cc:152] XLA service 0x77fca4003a90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747941298.675242  126242 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3050, Compute Capability 8.6
# 2025-05-23 01:14:59.168819: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747941301.413471  126242 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    4/2533 ━━━━━━━━━━━━━━━━━━━━ 2:09 51ms/step - AUC: 0.5419 - Precision: 0.1186 - Recall: 0.0938 - accuracy: 0.2135 - loss: 4.3694
# I0000 00:00:1747941324.255344  126242 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 237s 77ms/step - AUC: 0.9218 - Precision: 0.7246 - Recall: 0.6605 - accuracy: 0.6951 - loss: 1.3140 - val_AUC: 0.7660 - val_Precision: 0.5282 - val_Recall: 0.5205 - val_accuracy: 0.5252 - val_loss: 87.2753 - learning_rate: 0.0010
# Epoch 2/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 164s 65ms/step - AUC: 0.9747 - Precision: 0.8631 - Recall: 0.8334 - accuracy: 0.8470 - loss: 0.6376 - val_AUC: 0.8030 - val_Precision: 0.5178 - val_Recall: 0.4929 - val_accuracy: 0.5047 - val_loss: 13.2771 - learning_rate: 0.0010
# Epoch 3/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 167s 66ms/step - AUC: 0.9766 - Precision: 0.8685 - Recall: 0.8395 - accuracy: 0.8532 - loss: 0.6076 - val_AUC: 0.9825 - val_Precision: 0.8856 - val_Recall: 0.8685 - val_accuracy: 0.8760 - val_loss: 0.4901 - learning_rate: 0.0010
━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - AUC: 0.9953 - Precision: 0.9483 - Recall: 0.9406 - accuracy: 0.9444 - loss: 0.1902
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 175s 69ms/step - AUC: 0.9953 - Precision: 0.9483 - Recall: 0.9406 - accuracy: 0.9444 - loss: 0.1902 - val_AUC: 0.9932 - val_Precision: 0.9398 - val_Recall: 0.9343 - val_accuracy: 0.9378 - val_loss: 0.2124 - learning_rate: 0.0010
# Epoch 14/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 176s 69ms/step - AUC: 0.9972 - Precision: 0.9642 - Recall: 0.9605 - accuracy: 0.9624 - loss: 0.1198 - val_AUC: 0.9972 - val_Precision: 0.9598 - val_Recall: 0.9579 - val_accuracy: 0.9583 - val_loss: 0.1195 - learning_rate: 1.0000e-04
# Epoch 15/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 177s 70ms/step - AUC: 0.9983 - Precision: 0.9686 - Recall: 0.9650 - accuracy: 0.9668 - loss: 0.1033 - val_AUC: 0.9979 - val_Precision: 0.9641 - val_Recall: 0.9610 - val_accuracy: 0.9626 - val_loss: 0.1171 - learning_rate: 1.0000e-04
# Epoch 16/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 178s 70ms/step - AUC: 0.9988 - Precision: 0.9718 - Recall: 0.9690 - accuracy: 0.9702 - loss: 0.0920 - val_AUC: 0.9977 - val_Precision: 0.9633 - val_Recall: 0.9622 - val_accuracy: 0.9630 - val_loss: 0.1158 - learning_rate: 1.0000e-04
# Epoch 17/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 179s 71ms/step - AUC: 0.9986 - Precision: 0.9730 - Recall: 0.9705 - accuracy: 0.9719 - loss: 0.0850 - val_AUC: 0.9978 - val_Precision: 0.9673 - val_Recall: 0.9654 - val_accuracy: 0.9661 - val_loss: 0.1084 - learning_rate: 1.0000e-04
# Epoch 18/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 180s 71ms/step - AUC: 0.9986 - Precision: 0.9742 - Recall: 0.9713 - accuracy: 0.9725 - loss: 0.0805 - val_AUC: 0.9984 - val_Precision: 0.9645 - val_Recall: 0.9622 - val_accuracy: 0.9634 - val_loss: 0.1056 - learning_rate: 1.0000e-04
# Epoch 19/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 181s 72ms/step - AUC: 0.9989 - Precision: 0.9748 - Recall: 0.9716 - accuracy: 0.9732 - loss: 0.0795 - val_AUC: 0.9975 - val_Precision: 0.9637 - val_Recall: 0.9610 - val_accuracy: 0.9618 - val_loss: 0.1192 - learning_rate: 1.0000e-04
# Epoch 20/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 183s 72ms/step - AUC: 0.9991 - Precision: 0.9738 - Recall: 0.9717 - accuracy: 0.9727 - loss: 0.0787 - val_AUC: 0.9982 - val_Precision: 0.9617 - val_Recall: 0.9594 - val_accuracy: 0.9602 - val_loss: 0.1093 - learning_rate: 1.0000e-04
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 207s 82ms/step - AUC: 0.9991 - Precision: 0.9773 - Recall: 0.9759 - accuracy: 0.9764 - loss: 0.0697 - val_AUC: 0.9984 - val_Precision: 0.9637 - val_Recall: 0.9626 - val_accuracy: 0.9634 - val_loss: 0.1113 - learning_rate: 1.0000e-07
# Epoch 37/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 207s 82ms/step - AUC: 0.9991 - Precision: 0.9794 - Recall: 0.9761 - accuracy: 0.9776 - loss: 0.0691 - val_AUC: 0.9980 - val_Precision: 0.9657 - val_Recall: 0.9646 - val_accuracy: 0.9654 - val_loss: 0.1066 - learning_rate: 1.0000e-07
# Epoch 38/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 208s 82ms/step - AUC: 0.9992 - Precision: 0.9767 - Recall: 0.9741 - accuracy: 0.9755 - loss: 0.0681 - val_AUC: 0.9972 - val_Precision: 0.9696 - val_Recall: 0.9685 - val_accuracy: 0.9689 - val_loss: 0.1089 - learning_rate: 1.0000e-07
# Epoch 39/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - AUC: 0.9993 - Precision: 0.9798 - Recall: 0.9775 - accuracy: 0.9783 - loss: 0.0626
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 211s 83ms/step - AUC: 0.9993 - Precision: 0.9798 - Recall: 0.9775 - accuracy: 0.9783 - loss: 0.0626 - val_AUC: 0.9974 - val_Precision: 0.9661 - val_Recall: 0.9642 - val_accuracy: 0.9654 - val_loss: 0.1039 - learning_rate: 1.0000e-07
# Epoch 40/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 211s 83ms/step - AUC: 0.9993 - Precision: 0.9779 - Recall: 0.9761 - accuracy: 0.9772 - loss: 0.0685 - val_AUC: 0.9978 - val_Precision: 0.9680 - val_Recall: 0.9654 - val_accuracy: 0.9665 - val_loss: 0.1076 - learning_rate: 1.0000e-08
# Epoch 41/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 213s 84ms/step - AUC: 0.9992 - Precision: 0.9814 - Recall: 0.9792 - accuracy: 0.9806 - loss: 0.0610 - val_AUC: 0.9972 - val_Precision: 0.9661 - val_Recall: 0.9646 - val_accuracy: 0.9650 - val_loss: 0.1134 - learning_rate: 1.0000e-08
# Epoch 42/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 212s 84ms/step - AUC: 0.9990 - Precision: 0.9786 - Recall: 0.9767 - accuracy: 0.9776 - loss: 0.0658 - val_AUC: 0.9972 - val_Precision: 0.9681 - val_Recall: 0.9665 - val_accuracy: 0.9677 - val_loss: 0.1052 - learning_rate: 1.0000e-08
# Epoch 43/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 216s 85ms/step - AUC: 0.9992 - Precision: 0.9800 - Recall: 0.9771 - accuracy: 0.9784 - loss: 0.0667 - val_AUC: 0.9983 - val_Precision: 0.9645 - val_Recall: 0.9626 - val_accuracy: 0.9626 - val_loss: 0.1023 - learning_rate: 1.0000e-08
# Epoch 44/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 216s 85ms/step - AUC: 0.9990 - Precision: 0.9801 - Recall: 0.9773 - accuracy: 0.9784 - loss: 0.0673 - val_AUC: 0.9977 - val_Precision: 0.9708 - val_Recall: 0.9673 - val_accuracy: 0.9685 - val_loss: 0.1061 - learning_rate: 1.0000e-08
# Epoch 45/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 216s 85ms/step - AUC: 0.9992 - Precision: 0.9802 - Recall: 0.9781 - accuracy: 0.9788 - loss: 0.0612 - val_AUC: 0.9974 - val_Precision: 0.9649 - val_Recall: 0.9642 - val_accuracy: 0.9650 - val_loss: 0.1067 - learning_rate: 1.0000e-08
# Epoch 46/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 219s 86ms/step - AUC: 0.9993 - Precision: 0.9803 - Recall: 0.9773 - accuracy: 0.9785 - loss: 0.0644 - val_AUC: 0.9971 - val_Precision: 0.9637 - val_Recall: 0.9622 - val_accuracy: 0.9626 - val_loss: 0.1148 - learning_rate: 1.0000e-08
# Epoch 47/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 220s 87ms/step - AUC: 0.9991 - Precision: 0.9776 - Recall: 0.9758 - accuracy: 0.9765 - loss: 0.0681 - val_AUC: 0.9968 - val_Precision: 0.9618 - val_Recall: 0.9602 - val_accuracy: 0.9610 - val_loss: 0.1215 - learning_rate: 1.0000e-08
# Epoch 48/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 221s 87ms/step - AUC: 0.9990 - Precision: 0.9773 - Recall: 0.9748 - accuracy: 0.9762 - loss: 0.0725 - val_AUC: 0.9986 - val_Precision: 0.9708 - val_Recall: 0.9697 - val_accuracy: 0.9705 - val_loss: 0.0921 - learning_rate: 1.0000e-08
# Epoch 49/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 222s 88ms/step - AUC: 0.9995 - Precision: 0.9812 - Recall: 0.9791 - accuracy: 0.9801 - loss: 0.0599 - val_AUC: 0.9984 - val_Precision: 0.9692 - val_Recall: 0.9669 - val_accuracy: 0.9677 - val_loss: 0.0952 - learning_rate: 1.0000e-08
# Epoch 50/50
# 2533/2533 ━━━━━━━━━━━━━━━━━━━━ 222s 88ms/step - AUC: 0.9994 - Precision: 0.9814 - Recall: 0.9794 - accuracy: 0.9806 - loss: 0.0614 - val_AUC: 0.9986 - val_Precision: 0.9684 - val_Recall: 0.9657 - val_accuracy: 0.9665 - val_loss: 0.1017 - learning_rate: 1.0000e-08

# %%
model.save('all_models/MobileNetV3Large.keras')

# %%
model.evaluate(test_generator)
# Out:
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - AUC: 0.9983 - Precision: 0.9833 - Recall: 0.9823 - accuracy: 0.9824 - loss: 0.0564
# [0.0720512792468071,
#  0.9780993461608887,
#  0.9792401194572449,
#  0.9777082800865173,
#  0.9977810978889465]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.title("Learning curve", fontsize=16)
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend()
plt.savefig('learning_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Accuracy", fontsize=16)
plt.plot(history.history["accuracy"], label="Accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('accuracy_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Loss", fontsize=16)
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('loss_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Precision", fontsize=16)
plt.plot(history.history["Precision"], label="precision")
plt.plot(history.history["val_Precision"], label="val_precision")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('precision_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation Recall", fontsize=16)
plt.plot(history.history["Recall"], label="recall")
plt.plot(history.history["val_Recall"], label="val_recall")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('recall_curve.pdf')

# %%
plt.figure(figsize=(8, 8))
plt.title("Training and Validation AUC", fontsize=16)
plt.plot(history.history["AUC"], label="AUC")
plt.plot(history.history["val_AUC"], label="val_AUC")
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("value (log scale)", fontsize=14)
plt.legend();
plt.savefig('auc_curve.pdf')

# %%
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step

# %%
# Binarize true labels
y_true_bin = label_binarize(y_true, classes=list(range(len(class_names))))

plt.figure(figsize=(10, 8))
for i in range(len(class_names)):
    precision, recall, _ = precision_recall_curve(
        y_true_bin[:, i], y_pred_probs[:, i])
    plt.plot(recall, precision, lw=2, label=f'{class_names[i]}')

plt.xlabel('Recall', fontsize=14)
plt.ylabel('Precision', fontsize=14)
plt.title('Precision-Recall Curve', fontsize=16)
plt.legend(loc='best')
plt.grid(True)
plt.savefig('precision_recall_curve.pdf')
plt.show()

# %%
# ROC Curve
y_true_bin = label_binarize(y_true, classes=list(range(num_classes)))
fpr = dict()
tpr = dict()
roc_auc = dict()

plt.figure(figsize=(10, 8))
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    plt.plot(fpr[i], tpr[i],
             label=f'{class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve', fontsize=16)
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.legend(loc='lower right')
plt.grid()
plt.savefig('roc_curve.pdf')
plt.show()

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img('/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test/CSR/csr_train_2348.jpg',target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,axis=1)
if a==0:
      op="AMD"   
elif a==1:
    op='CNV'
elif a==2:
    op='CSR'
elif a==3:
    op='DME'
elif a==4:
    op='DR'
elif a==5:
    op='DRUSEN'
elif a==6:
    op='MH'
else:
      op="Normal"
plt.imshow(img)
print("THE UPLOADED OCT IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# [[1.4529459e-21 6.0571492e-22 1.0000000e+00 8.2729429e-32 6.8578685e-21
#   2.4582829e-31 1.4319705e-21 1.0229235e-27]]
# THE UPLOADED OCT IMAGE IS: CSR

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img('/home/nemo/Documents/Coding/AI/Retinal_OCT/dataset/test/NORMAL/no_2497093_3.jpg',target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,axis=1)
if a==0:
      op="AMD"   
elif a==1:
    op='CNV'
elif a==2:
    op='CSR'
elif a==3:
    op='DME'
elif a==4:
    op='DR'
elif a==5:
    op='DRUSEN'
elif a==6:
    op='MH'
else:
      op="Normal"
plt.imshow(img)
print("THE UPLOADED OCT IMAGE IS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[2.2762078e-01 7.6556926e-06 5.1055784e-05 1.6561554e-04 7.3103632e-07
#   6.9556327e-04 2.8656050e-08 7.7145857e-01]]
# THE UPLOADED OCT IMAGE IS: Normal

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Get true labels
y_true = validation_generator.classes

# Predict probabilities
y_pred_prob = model.predict(validation_generator)

# Convert probabilities to class indices
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 318/318 ━━━━━━━━━━━━━━━━━━━━ 21s 64ms/step

# %%
class_labels = list(validation_generator.class_indices.keys())

# %%
cm = confusion_matrix(y_true, y_pred)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("EfficientNetB3 Confusion Matrix", fontsize=16)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.show()
plt.savefig('confusion_matrix.pdf')

# %%
cm_normalized = confusion_matrix(y_true, y_pred, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("Normalized Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report


report = classification_report(y_true, y_pred, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          AMD       0.99      0.99      0.99       436
#          CNV       0.95      0.90      0.92       299
#          CSR       1.00      1.00      1.00       299
#          DME       0.93      0.96      0.94       314
#           DR       1.00      1.00      1.00       299
#       DRUSEN       0.93      0.92      0.92       299
#           MH       1.00      1.00      1.00       273
#       NORMAL       0.93      0.95      0.94       321
#
#     accuracy                           0.97      2540
#    macro avg       0.96      0.96      0.96      2540
# weighted avg       0.97      0.97      0.97      2540

# %% [markdown]
# ## Inference Time

# %%
import time
import numpy as np

# Assuming 'model' is your trained Keras model
# Assuming 'validation_generator' or a similar data source is available

# --- Prepare your inference data ---
# Get one batch for inference timing.
# Make sure validation_generator is properly initialized and can yield a batch.
# If your generator shuffles, reset it for consistent batch content if needed.
validation_generator.reset()
X_inference_batch, _ = next(validation_generator) # Use next() to get a single batch

print(f"Shape of inference batch: {X_inference_batch.shape}")
print(f"Batch size: {X_inference_batch.shape[0]}")

# --- 1. Warm-up runs (recommended) ---
print("\nPerforming warm-up runs...")
for _ in range(5): # Run 5 warm-up predictions
    _ = model.predict(X_inference_batch, verbose=0)
print("Warm-up complete.")

# --- 2. Measure inference time for a single batch (per step) ---
num_measurements = 100 # Number of times to repeat the measurement for averaging
inference_times_sec_per_step = []

print(f"\nMeasuring inference time over {num_measurements} repetitions...")
for _ in range(num_measurements):
    start_time = time.time()
    _ = model.predict(X_inference_batch, verbose=0) # Set verbose=0 to suppress progress bar
    end_time = time.time()
    inference_times_sec_per_step.append(end_time - start_time)

# Calculate average time per step in seconds
average_inference_time_sec_per_step = np.mean(inference_times_sec_per_step)
std_inference_time_sec_per_step = np.std(inference_times_sec_per_step)

# Convert to milliseconds per step
average_inference_time_ms_per_step = average_inference_time_sec_per_step * 1000
std_inference_time_ms_per_step = std_inference_time_sec_per_step * 1000

print(f"\nAverage inference time per step (batch size {X_inference_batch.shape[0]}):")
print(f"  {average_inference_time_ms_per_step:.4f} ms/step (Std Dev: {std_inference_time_ms_per_step:.4f} ms/step)")

# Optional: Calculate ms/sample if desired
samples_in_batch = X_inference_batch.shape[0]
if samples_in_batch > 0:
    average_inference_time_ms_per_sample = average_inference_time_ms_per_step / samples_in_batch
    print(f"  {average_inference_time_ms_per_sample:.4f} ms/sample")

# --- Example for total inference time over the whole validation set ---
# If you want to know the ms/step for the entire generator, you would need to
# divide the total inference time by the number of steps (batches) in the generator.

print("\nMeasuring total inference time for the entire validation set...")
validation_generator.reset() # Reset generator for a full pass
num_validation_steps = len(validation_generator) # Get the total number of batches

overall_inference_start_time = time.time()
_ = model.predict(validation_generator, verbose=1) # verbose=1 to see progress
overall_inference_end_time = time.time()

total_validation_inference_time_sec = overall_inference_end_time - overall_inference_start_time
total_validation_inference_time_ms = total_validation_inference_time_sec * 1000

# Calculate average ms/step for the entire validation set pass
if num_validation_steps > 0:
    average_ms_per_step_full_pass = total_validation_inference_time_ms / num_validation_steps
    print(f"Total inference time for validation set: {total_validation_inference_time_ms:.2f} ms")
    print(f"Average ms/step over entire validation set ({num_validation_steps} steps): {average_ms_per_step_full_pass:.4f} ms/step")
else:
    print("Validation generator has no steps.")
# Out:
# Shape of inference batch: (8, 224, 224, 3)
# Batch size: 8
#
# Performing warm-up runs...
# Warm-up complete.
#
# Measuring inference time over 100 repetitions...
#
# Average inference time per step (batch size 8):
#   55.7204 ms/step (Std Dev: 1.6469 ms/step)
#   6.9650 ms/sample
#
# Measuring total inference time for the entire validation set...
# 318/318 ━━━━━━━━━━━━━━━━━━━━ 19s 59ms/step
# Total inference time for validation set: 19030.57 ms
# Average ms/step over entire validation set (318 steps): 59.8445 ms/step

# %%
history.history.keys()
# Out:
# dict_keys(['AUC', 'Precision', 'Recall', 'accuracy', 'loss', 'val_AUC', 'val_Precision', 'val_Recall', 'val_accuracy', 'val_loss', 'learning_rate'])

# %%
history.params
# Out:
# {'verbose': 'auto', 'epochs': 50, 'steps': 634}

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
print(tf.keras.__version__)
# Out:
# 3.9.2
